# %%
import pickle
import pandas as pd 
import numpy as np

# %%
# Shared folder to read data
SHARED_FOLDER = './yelp'

# Your folder to write new data and create notebooks.
MY_FOLDER = './output'

# %%
with open ('{}/tip.pickle'.format(SHARED_FOLDER), 'rb') as f:
    tip_df = pickle.load(f)
example_tip_df=tip_df.head(2000)
example_tip_df
# Out:
#                  business_id        date  \
# 0     CgZG8x59kWo4-wVt5vHT4w  2011-10-17
# 1     aJMhN4fdsARaJCw-dGvNGw  2013-09-25
# 2     YLE61MXFI-t1raVqQfeBWQ  2012-04-07
# 3     lg1BrK8zf2DVkUdbwkTkSw  2012-03-22
# 4     DoEMzev54WS8_lVLJ3NoqQ  2014-09-12
# 5     DWZM3Qw0WJminDcXoBE_eA  2013-07-08
# 6     v4OSsdIipqscDn-VqFqCzw  2013-01-26
# 7     9ee9VqXJBYlF3gQELzLlNw  2012-02-14
# 8     By_GCpCBPCXMQkEBR4hymQ  2012-07-07
# 9     kHa99CK7IFsiluoTsIkdVw  2013-09-28
# 10    nZgYNbl1XlZyyKlISMoG6w  2011-10-29
# 11    Hieqsu3u1peZ2I2jPwiKHw  2014-01-02
# 12    TgIJfXqEKE-JsD0QUoaC5Q  2014-06-25
# 13    tngPZihXlUG_cj4zw1ne3g  2014-04-07
# 14    LmVcYycG_VI3S6RNgqiriw  2012-06-14
# 15    DHk8is9rvfnATsW1AudWQg  2013-05-29
# 16    4MB98W98rKBU0X26pTbw0w  2015-04-24
# 17    yxxLFua918P53BQADGCSCw  2014-03-04
# 18    Ni9aqkG_fNWrH02VNlRhLQ  2012-04-28
# 19    g3BOFNiBxK5ukUn3aBvQRA  2011-10-13
# 20    lut0g04VsYRyblR1Ad-8HA  2011-07-01
# 21    4jMoBw4215N9GNXWRqO2ZA  2012-08-17
# 22    e59shAZKfnDfH9O4TuIdLg  2015-11-21
# 23    6IRoWd6N__OVMNQfvu1Ccw  2011-07-24
# 24    4n_KDjH3dQCIxHZ3SWVO6g  2012-01-24
# 25    dKtbrGgg5fbl8MibhilP2A  2013-02-04
# 26    wN_wAXWg8W94v04eqijy6g  2011-07-11
# 27    HFhSObXGnsvn6V7KX6cYow  2013-04-12
# 28    npfVfumxVAkQNYpY1fSvew  2010-12-26
# 29    VY_tvNUCCXGXQeSvJl757Q  2012-01-29
# ...                      ...         ...
# 1970  tb24fvNJfHhyKEXkKn12Xw  2015-11-06
# 1971  3rNsz7qxJTyyQPGUYGDmsg  2013-07-01
# 1972  wv2AUfRGki23WqQ5nul6Pw  2011-05-15
# 1973  D669LTmtNr13lnszmdkllg  2013-02-10
# 1974  xQ0jGoeoR2aku8oURjFnRQ  2015-11-24
# 1975  50nln4YPr0QDo_v1uBmHfg  2011-06-10
# 1976  A4aCnacn3bCoJrLmNRYgCA  2012-06-26
# 1977  tbTc7094zwIYAtU-0NkU4w  2015-09-05
# 1978  X2yJhPdGxRwOzKnFOXEyaw  2011-03-10
# 8                    Brisket, chicken and ribs, baby!!!  tip
# 9                     Must try the pumpkin funnel cake!  tip
# 10                            Pizza time to sober me up  tip
# 11    Let me just make it simple. The servers were a...  tip
# 12    $9.95 soup salad and sandwich lunch special wa...  tip
# 13    Very good, very busy at lunch and very afforda...  tip
# 14                               Great customer service  tip
# 15                        Giovanni wings are delicious!  tip
# 16                    My husband and I love this place!  tip
# 17    They have so many Vegan....and non Vegan items...  tip
# 18    Getting my pho, didn't feel like driving far s...  tip
# 19    Ask for the best price, saved me $5 on a smog ...  tip
# 20                      Erica's 21st birthday! Woo hoo!  tip
# 21                 Mr. Blacks shiraz is the wine to try  tip
# 22    The menu advertises cheddar on the Triple B bu...  tip
# 23              Prodigy dinner to get the week started.  tip
# 24                   A taste of india...we're obsessed!  tip
# 25                     Great breakfast and orange juice  tip
# 26    My first time here. Need to come back. The Oax...  tip
# 27    This place was great. The menu options were de...  tip
# 28               1 + hour wait to get in SCReW that !!!  tip
# 29    First time. Been long enough. Wanted to check ...  tip
# ...                                                 ...  ...
# 1970  Love this place. Unique and fun. Really good f...  tip
# 1971  Hot Giardiniera available to stuff in your stu...  tip
# 1972                                                Blt  tip
# 1973              The only place that sells Baja Blast.  tip
# 1974                          Amazing customer service!  tip
# 1975                                      Macaroons!!!!  tip
# 1976  Two good men is open and still provides except...  tip
# 1977  Tight Slots. Ghetto clientele. Their player cl...  tip
# 1978                Ask for the special spicy sauce!!!!  tip
# 1979                                You guys Suck!!!!!!  tip
# 1980  Quick, friendly service and an expertly made l...  tip
# 1981                                       Hi to Mario!  tip
# 1982                       They have weekend happy hour  tip
# 1983  best shabu shabu in town for AYCE. i think its...  tip
# 1984                         Porter loves to play here.  tip
# 1985                          First time, it was great!  tip
# 1986  Steak special with a beer $8.99.  You just hav...  tip
# 1987  Make sure to check out their menu! They have a...  tip
# 1988                                     Nice playplace  tip
# 1989                 $2 breakfast sandwiches this week.  tip
# 1990                                     It's so good!!  tip
# 1991                                     Like it so far  tip
# 1992  Nice place. Fresh baked bread, smells deliciou...  tip
# 1993  Head to the office for birthday groups. The gr...  tip
# 1994                                          New items  tip
# 1995  Best place to get a roast beef po boy as close...  tip
# 1996  Get the Mango Jelly Ice, it's pretty good a to...  tip
# 1997  They can't take coupons on a phone. Must print...  tip
# 1998                                Best gyros in town!  tip
# 1999  Love the misto can't get enough of the zucchin...  tip
#
#                      user_id
# 0     UOtiAn0T72gjdHg9tjVPew
# 1     r-XaXDBEXNTROAOFBtfy-A
# 2     V0iZ6gMTHQDYxypIhR2PTg
# 3     hqdkCwCKBaVzHl4YHy_8sQ
# 4     B0cYyDmeo3JJsNy0Uf73FA
# 5     Iyo5_VTGhFYDyBAAjPrHXw
# 6     JB9YcOmb5O5tl8SvSohffw
# 7     n5PtmHO-PSHiyseG56XZtA
# 8     jqT0tePwrENrVRLzCB5c4w
# 9     kE7e1I22h7ymiJtcESjNxQ
# 1998  ivi5jHjmf2uV8faGJ9Rfig
# 1999  83DsSlg-swjLzmZnUzq2UA
#
#                                                    text
# 0     Pisco Sour with ceviche classic is a great way...
# 1     This is a hidden place.  It is located in a st...
# 2                                      Artopia tonight!
# 3        Always a good alternative to Pasta Ristorante.
# 4                                       Michelin 1 star
# 5     I'm not a huge burger fan or ever have a hunch...
# 6     Best way to house shop: Buy different options,...
# 7     Just got my eyelash extensions done here with ...
# 8                    Brisket, chicken and ribs, baby!!!
# 9                     Must try the pumpkin funnel cake!
# 10                            Pizza time to sober me up
# 11    Let me just make it simple. The servers were a...
# 12    $9.95 soup salad and sandwich lunch special wa...
# 13    Very good, very busy at lunch and very afforda...
# 14                               Great customer service
# 15                        Giovanni wings are delicious!
# 16                    My husband and I love this place!
# 17    They have so many Vegan....and non Vegan items...
# 18    Getting my pho, didn't feel like driving far s...
# 19    Ask for the best price, saved me $5 on a smog ...
# 20                      Erica's 21st birthday! Woo hoo!
# 21                 Mr. Blacks shiraz is the wine to try
# 22    The menu advertises cheddar on the Triple B bu...
# 23              Prodigy dinner to get the week started.
# 24                   A taste of india...we're obsessed!
# 25                     Great breakfast and orange juice
# 26    My first time here. Need to come back. The Oax...
# 27    This place was great. The menu options were de...
# 28               1 + hour wait to get in SCReW that !!!
# 29    First time. Been long enough. Wanted to check ...
# ...                                                 ...
# 1970  Love this place. Unique and fun. Really good f...
# 1971  Hot Giardiniera available to stuff in your stu...
# 1972                                                Blt
# 1973              The only place that sells Baja Blast.
# 1974                          Amazing customer service!
# 1975                                      Macaroons!!!!
# 1976  Two good men is open and still provides except...
# 1977  Tight Slots. Ghetto clientele. Their player cl...
# 1978                Ask for the special spicy sauce!!!!
# 1979                                You guys Suck!!!!!!
# 1980  Quick, friendly service and an expertly made l...
# 1981                                       Hi to Mario!
# 1982                       They have weekend happy hour
# 1983  best shabu shabu in town for AYCE. i think its...
# 1984                         Porter loves to play here.
# 1985                          First time, it was great!
# 1986  Steak special with a beer $8.99.  You just hav...
# 1987  Make sure to check out their menu! They have a...
# 1988                                     Nice playplace
# 1989                 $2 breakfast sandwiches this week.
# 1990                                     It's so good!!
# 1991                                     Like it so far
# 1992  Nice place. Fresh baked bread, smells deliciou...
# 1993  Head to the office for birthday groups. The gr...
# 1994                                          New items
# 1995  Best place to get a roast beef po boy as close...
# 1996  Get the Mango Jelly Ice, it's pretty good a to...
# 1997  They can't take coupons on a phone. Must print...
# 1998                                Best gyros in town!
# 1999  Love the misto can't get enough of the zucchin...
#
# [2000 rows x 2 columns]

# %%
import re
def clean_email_text(text):
    text = text.replace('\n'," ") #new line
    text = re.sub(r"-", " ", text) #separate two words with"-" (july-edu ==> july edu）
    text = re.sub(r"[0-9]+", "", text) #number
    pure_text = ''
    # filter all number and signs
    for letter in text:
        # just letter and blank
        if letter.isalpha() or letter==' ':
            pure_text += letter
    # filter all single words
    text = ' '.join(word for word in pure_text.split() if len(word)>1)
    return text

# %%
with open('stopwords.txt', 'r') as f:  
    stopWords=[l.strip('\n') for l in f.readlines()]
print(stopWords)
# Out:
# ['a', "a's", 'al', 'able', 'about', 'above', 'according', 'accordingly', 'across', 'actually', 'after', 'afterwards', 'again', 'against', "ain't", 'all', 'allow', 'allows', 'almost', 'alone', 'along', 'already', 'also', 'although', 'always', 'am', 'among', 'amongst', 'an', 'and', 'another', 'any', 'anybody', 'anyhow', 'anyone', 'anything', 'anyway', 'anyways', 'anywhere', 'apart', 'appear', 'appreciate', 'appropriate', 'are', "aren't", 'around', 'as', 'aside', 'ask', 'asking', 'associated', 'at', 'available', 'away', 'awfully', 'b', 'be', 'became', 'because', 'become', 'becomes', 'becoming', 'been', 'before', 'beforehand', 'behind', 'being', 'believe', 'below', 'beside', 'besides', 'best', 'better', 'between', 'beyond', 'both', 'brief', 'but', 'by', 'c', "c'mon", "c's", 'came', 'can', "can't", 'cannot', 'cant', 'cause', 'causes', 'certain', 'certainly', 'changes', 'clearly', 'co', 'com', 'come', 'comes', 'concerning', 'consequently', 'consider', 'considering', 'contain', 'containing', 'contains', 'corresponding', 'could', "couldn't", 'course', 'currently', 'd', 'definitely', 'described', 'despite', 'did', "didn't", 'different', 'do', 'does', "doesn't", 'doing', "don't", 'done', 'down', 'downwards', 'during', 'e', 'each', 'edu', 'eg', 'eight', 'either', 'else', 'elsewhere', 'enough', 'entirely', 'especially', 'et', 'etc', 'even', 'ever', 'every', 'everybody', 'everyone', 'everything', 'everywhere', 'ex', 'exactly', 'example', 'except', 'f', 'far', 'few', 'fifth', 'first', 'five', 'followed', 'following', 'follows', 'for', 'former', 'formerly', 'forth', 'four', 'from', 'further', 'furthermore', 'g', 'get', 'gets', 'getting', 'given', 'gives', 'go', 'goes', 'going', 'gone', 'got', 'gotten', 'greetings', 'h', 'had', "hadn't", 'happens', 'hardly', 'has', "hasn't", 'have', "haven't", 'having', 'he', "he's", 'hello', 'help', 'hence', 'her', 'here', "here's", 'hereafter', 'hereby', 'herein', 'hereupon', 'hers', 'herself', 'hi', 'him', 'himself', 'his', 'hither', 'hopefully', 'how', 'howbeit', 'however', 'i', "i'd", "i'll", "i'm", "i've", 'ie', 'if', 'ignored', 'immediate', 'in', 'inasmuch', 'inc', 'indeed', 'indicate', 'indicated', 'indicates', 'inner', 'insofar', 'instead', 'into', 'inward', 'is', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', 'j', 'just', 'k', 'keep', 'keeps', 'kept', 'know', 'knows', 'known', 'l', 'last', 'lately', 'later', 'latter', 'latterly', 'least', 'less', 'lest', 'let', "let's", 'like', 'liked', 'likely', 'little', 'look', 'looking', 'looks', 'ltd', 'm', 'mainly', 'many', 'may', 'maybe', 'me', 'mean', 'meanwhile', 'merely', 'might', 'more', 'moreover', 'most', 'mostly', 'much', 'must', 'my', 'myself', 'n', 'name', 'namely', 'nd', 'near', 'nearly', 'necessary', 'need', 'needs', 'neither', 'never', 'nevertheless', 'new', 'next', 'nine', 'no', 'nobody', 'non', 'none', 'noone', 'nor', 'normally', 'not', 'nothing', 'novel', 'now', 'nowhere', 'o', 'obviously', 'of', 'off', 'often', 'oh', 'ok', 'okay', 'old', 'on', 'once', 'one', 'ones', 'only', 'onto', 'or', 'other', 'others', 'otherwise', 'ought', 'our', 'ours', 'ourselves', 'out', 'outside', 'over', 'overall', 'own', 'p', 'particular', 'particularly', 'per', 'perhaps', 'placed', 'please', 'plus', 'possible', 'presumably', 'probably', 'provides', 'q', 'que', 'quite', 'qv', 'r', 'rather', 'rd', 're', 'really', 'reasonably', 'regarding', 'regardless', 'regards', 'relatively', 'respectively', 'right', 's', 'said', 'same', 'saw', 'say', 'saying', 'says', 'second', 'secondly', 'see', 'seeing', 'seem', 'seemed', 'seeming', 'seems', 'seen', 'self', 'selves', 'sensible', 'sent', 'serious', 'seriously', 'seven', 'several', 'shall', 'she', 'should', "shouldn't", 'since', 'six', 'so', 'some', 'somebody', 'somehow', 'someone', 'something', 'sometime', 'sometimes', 'somewhat', 'somewhere', 'soon', 'sorry', 'specified', 'specify', 'specifying', 'still', 'sub', 'such', 'sup', 'sure', 't', "t's", 'take', 'taken', 'tell', 'tends', 'th', 'than', 'thank', 'thanks', 'thanx ...

# %%
df.text = df.text.apply(lambda s: clean_email_text(s))

# %%
df.text[12]
# Out:
# 'soup salad and sandwich lunch special was amazing great value and better food'

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
n_features = 1000
tf_vectorizer = CountVectorizer(strip_accents = 'unicode',
                                ngram_range=(2, 3),
                                max_features=n_features,
                                stop_words=stopWords)
tf = tf_vectorizer.fit_transform(df.text)

# %%
from sklearn.decomposition import LatentDirichletAllocation

# %%
n_topics = 5
lda = LatentDirichletAllocation(n_topics=n_topics, max_iter=50,
                                learning_method='online',
                                learning_offset=50.,
                                random_state=0)
lda.fit(tf)
# Out:
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#              evaluate_every=-1, learning_decay=0.7,
#              learning_method='online', learning_offset=50.0,
#              max_doc_update_iter=100, max_iter=50, mean_change_tol=0.001,
#              n_jobs=1, n_topics=5, perp_tol=0.1, random_state=0,
#              topic_word_prior=None, total_samples=1000000.0, verbose=0)

# %%
def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print("Topic #%d:" % topic_idx)
        print(" ".join([feature_names[i]
                        for i in topic.argsort()[:-n_top_words - 1:-1]]))
    print()

# %%
n_top_words = 20
tf_feature_names = tf_vectorizer.get_feature_names()
print_top_words(lda, tf_feature_names, n_top_words)
# Out:
# Topic #0:
# love place great food coming back lunch specials nice food horrible service staff great food fresh lunch special onion rings prime rib nice staff good job awesome food highly recommended late night service slow fried rice love love pop lock
# Topic #1:
# happy hour friendly service wont back carne asada las vegas happy hour pm hour pm mac cheese pretty good players card food drinks fantastic food food back sooo good quick easy french toast great breakfast fast friendly dont miss taco tuesday
# Topic #2:
# good food food service customer service friendly staff food good good service mexican food bloody mary gluten free great customer service great customer service good half price prices good good back mary bar bloody mary bar green beans bar food outdoor seating
# Topic #3:
# great service service great ice cream food great nice place good place good food great lunch time great lunch place fresh place rocks food great service shabu shabu beer selection great selection open till delicious food service great food salted caramel long time
# Topic #4:
# great place place great slow service excellent service dont forget back great parking lot huge portions place great food chicken wings sunday brunch dont bother healthy options lunch dinner food court place cheap good price great experience service food awesome service

# %%
import pyLDAvis
import pyLDAvis.sklearn
pyLDAvis.enable_notebook()
pyLDAvis.sklearn.prepare(lda, tf, tf_vectorizer)
# Out:
# PreparedData(topic_coordinates=            Freq  cluster  topics         x         y
# topic
# 0      23.142368        1       1 -0.157861  0.129429
# 2      20.833277        1       2  0.170463  0.108826
# 3      19.879539        1       3 -0.037037 -0.101449
# 4      18.472510        1       4  0.009290 -0.033409
# 1      17.672305        1       5  0.015145 -0.103397, topic_info=     Category       Freq                    Term      Total  loglift  logprob
# term
# 268   Default  20.000000              love place  20.000000  30.0000  30.0000
# 217   Default  15.000000              happy hour  15.000000  29.0000  29.0000
# 197   Default  15.000000             great place  15.000000  28.0000  28.0000
# 188   Default  17.000000              great food  17.000000  27.0000  27.0000
# 156   Default  13.000000               good food  13.000000  26.0000  26.0000
# 203   Default  12.000000           great service  12.000000  25.0000  25.0000
# 129   Default  11.000000            food service  11.000000  24.0000  24.0000
# 70    Default  11.000000        customer service  11.000000  23.0000  23.0000
# 144   Default   9.000000          friendly staff   9.000000  22.0000  22.0000
# 927   Default   7.000000           service great   7.000000  21.0000  21.0000
# 236   Default   7.000000               ice cream   7.000000  20.0000  20.0000
# 120   Default   7.000000               food good   7.000000  19.0000  19.0000
# 122   Default   6.000000              food great   6.000000  18.0000  18.0000
# 169   Default   6.000000            good service   6.000000  17.0000  17.0000
# 142   Default   6.000000        friendly service   6.000000  16.0000  16.0000
# 64    Default   5.000000             coming back   5.000000  15.0000  15.0000
# 283   Default   5.000000            mexican food   5.000000  14.0000  14.0000
# 990   Default   4.000000               wont back   4.000000  13.0000  13.0000
# 39    Default   4.000000             carne asada   4.000000  12.0000  12.0000
# 27    Default   4.000000             bloody mary   4.000000  11.0000  11.0000
# 249   Default   4.000000               las vegas   4.000000  10.0000  10.0000
# 148   Default   4.000000             gluten free   4.000000   9.0000   9.0000
# 185   Default   4.000000  great customer service   4.000000   8.0000   8.0000
# 184   Default   4.000000          great customer   4.000000   7.0000   7.0000
# 941   Default   3.000000            slow service   3.000000   6.0000   6.0000
# 232   Default   3.000000                 hour pm   3.000000   5.0000   5.0000
# 218   Default   3.000000           happy hour pm   3.000000   4.0000   4.0000
# 99    Default   3.000000       excellent service   3.000000   3.0000   3.0000
# 276   Default   3.000000              mac cheese   3.000000   2.0000   2.0000
# 290   Default   4.000000              nice place   4.000000   1.0000   1.0000
# ...       ...        ...                     ...        ...      ...      ...
# 217    Topic5  15.205431              happy hour  15.730208   1.6992  -3.0767
# 990    Topic5   3.845332               wont back   4.371972   1.6048  -4.4515
# 39     Topic5   3.770353             carne asada   4.295614   1.6027  -4.4712
# 249    Topic5   3.630317               las vegas   4.155068   1.5982  -4.5091
# 232    Topic5   3.206040                 hour pm   3.730754   1.5816  -4.6333
# 218    Topic5   3.206040           happy hour pm   3.730754   1.5816  -4.6333
# 276    Topic5   3.152203              mac cheese   3.676967   1.5792  -4.6503
# 768    Topic5   2.989867             pretty good   3.515583   1.5712  -4.7032
# 763    Topic5   2.963101            players card   3.492695   1.5687  -4.7121
# 118    Topic5   2.525795             food drinks   3.050740   1.5443  -4.8718
# 104    Topic5   2.522498          fantastic food   3.051939   1.5426  -4.8731
# 112    Topic5   2.413683               food back   2.938823   1.5363  -4.9172
# 945    Topic5   2.376808               sooo good   2.901594   1.5337  -4.9326
# 142    Topic5   4.894922        friendly service   6.019459   1.5264  -4.2102
# 776    Topic5   1.999979              quick easy   2.524766   1.5002  -5.1052
# 136    Topic5   1.989510            french toast   2.514281   1.4991  -5.1105
# 182    Topic5   1.914317         great breakfast   2.439084   1.4909  -5.1490
# 106    Topic5   1.902080           fast friendly   2.426838   1.4895  -5.1554
# 89     Topic5   1.891545               dont miss   2.416310   1.4883  -5.1610
# 968    Topic5   1.885570            taco tuesday   2.410334   1.4876  -5.1642
# 767    Topic5   1.794856           prepared wait   2.319649   1.4767  -5.2135
# 689    Topic5   1.794418             place happy   2.325733   1.4738  -5.2137
# 991    Topic5   1.741389                 woo hoo   2.266128   1.4698  -5.2437
# 262    Topic5   1.414109            lots parking   1.938906   1.4175  -5.4519
# 183    Topic5   1.402693           great burgers   1.927488   1.4153  -5.4600
# 261    Topic5   1.402693              long waits   1.927488   1.4153  -5.4600
# 258    Topic5   1.400862               long line   1.927571   1.4140  -5.4613
# 67     Topic5   1.385815              cream corn   1.910566   1.4121  -5.4721
# 761    Topic5   1.389614             place worst   1.916242   1.4118  -5.4694
# 246    Topic5   1.380225               kids love   1.905018   1.4109  -5.4761
#
# [190 rows x 6 columns], token_table=      Topic      Freq                  Term
# term
# 2         1  0.775802         amazing great
# 7         3  0.802556      atmosphere great
# 9         2  0.838969     authentic mexican
# 11        1  0.898903          awesome food
# 12        3  0.323151       awesome service
# 12        4  0.646302       awesome service
# 13        4  0.931343            back great
# 14        4  0.515127    back great service
# 16        1  0.772476             back room
# 18        2  0.761384              bar food
# 23        1  0.312305        beer selection
# 23        3  0.624610        beer selection
# 27        2  0.836283           bloody mary
# 28        2  0.989547       bloody mary bar
# 39        5  0.931182           carne asada
# 49        4  0.509238          cheese steak
# 53        4  0.773355         chicken wings
# 56        1  0.765375           chips salsa
# 64        1  0.834195           coming back
# 67        5  0.523405            cream corn
# 69        4  0.512278      crispy delicious
# 70        2  0.980093      customer service
# 71        1  0.742248            date night
# 76        1  0.753895            deep fried
# 77        3  0.785148        delicious food
# 79        4  0.519551         demerit grade
# 80        4  0.510680             diet coke
# 81        1  0.609228           dining room
# 81        5  0.304614           dining room
# 83        4  0.503194           donar kebab
# ...     ...       ...                   ...
# 771       2  0.934454           prices good
# 773       1  0.883224             prime rib
# 776       5  0.792153            quick easy
# 777       4  0.844258        ranch dressing
# 782       2  0.840982  refreshing delicious
# 913       3  0.786811        salted caramel
# 922       4  0.806612          service food
# 925       2  0.804505          service good
# 927       3  0.948393         service great
# 928       3  0.785022    service great food
# 936       1  0.923569          service slow
# 937       3  0.714916           shabu shabu
# 939       3  0.816845             sign door
# 941       4  0.764534          slow service
# 942       1  0.752340             slow slow
# 945       5  0.689276             sooo good
# 946       3  0.330233            soooo good
# 946       4  0.660466            soooo good
# 953       3  0.795235        staff friendly
# 955       1  0.752776           staff great
# 960       1  0.750230          street tacos
# 962       4  0.776781         sunday brunch
# 964       2  0.766174            super fast
# 967       3  0.815139          sweet potato
# 968       5  0.829761          taco tuesday
# 970       4  0.516831              thai tea
# 986       1  0.735560       white chocolate
# 990       5  0.914919             wont back
# 991       5  0.882563               woo hoo
# 994       2  0.846997            worth wait
#
# [171 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[1, 3, 4, 5, 2])

# %%
#data = pyLDAvis.sklearn.prepare(lda, tf, tf_vectorizer)
#pyLDAvis.show(data)
