# %%
import pandas
import pickle

# %% [markdown]
# # Correlation

# %%
business_df=pandas.read_csv('business_df.csv')

# %%
Correlation=business_df.corr(method='pearson', min_periods=1)

# %%
type(Correlation)
# Out:
# pandas.core.frame.DataFrame

# %%
Correlation.columns
# Out:
# Index(['Unnamed: 0', 'latitude', 'longitude', 'open', 'review_count', 'stars',
#        'categories_Fastfood', 'categories_Sandwiches', 'categories_Pizza',
#        'categories_Vegetarian',
#        ...
#        'hours.Thursday.close', 'hours.Thursday.open', 'hours.Tuesday.close',
#        'hours.Tuesday.open', 'hours.Wednesday.close', 'hours.Wednesday.open',
#        'avg_review_stars', 'reviews_count', 'tip_count', 'checkin_count'],
#       dtype='object', length=112)

# %%
Correlation['stars']
# Out:
# Unnamed: 0                        -0.072913
# latitude                           0.033394
# longitude                          0.037874
# open                               0.029106
# review_count                       0.268753
# stars                              1.000000
# categories_Fastfood               -0.237099
# categories_Sandwiches             -0.131481
# categories_Pizza                  -0.074266
# categories_Vegetarian              0.104290
# categories_Barbeque               -0.012228
# categories_Tex-Mex                -0.007831
# Automotive                         0.104290
# categories_Restaurants            -0.157432
# categories_CoffeeTea               0.166480
# categories_American_Traditional    0.035714
# categories_Steakhouses             0.002253
# categories_Thai                    0.022700
# categories_American_New            0.017772
# categories_ChickenWings           -0.177505
# categories_Chinese                 0.034069
# ...

# %%
#L.to_csv('./Correlation avec stars.csv')

# %%
Correlation['stars']=abs(Correlation['stars'])

# %%
Correlation.sort_values(by='stars',ascending = False)['stars'].head(30)
# Out:
# stars                              1.000000
# avg_review_stars                   0.973334
# hours.Friday.open                  0.345733
# hours.Thursday.open                0.343465
# hours.Tuesday.open                 0.335533
# hours.Wednesday.open               0.335533
# hours.Saturday.open                0.326952
# hours.Monday.open                  0.271235
# reviews_count                      0.269547
# review_count                       0.268753
# tip_count                          0.259741
# attributes.Parking.valet           0.242529
# categories_Fastfood                0.237099
# attributes.Parking.validated       0.226209
# attributes.Parking.garage          0.198562
# attributes.GoodFor.latenight       0.195359
# attributes.Parking.street          0.186030
# categories_ChickenWings            0.177505
# attributes.WiFi                    0.174391
# attributes.WheelchairAccessible    0.173612
# hours.Sunday.open                  0.169657
# ...

# %%
SHARED_FOLDER = '/Users/feelaamr/Documents/projet-big-data/data yelp'

# %% [markdown]
# # Partie 2
# ## Division en 5 catégories principales

# %%
import sys
# 1
import pandas.core.indexes 
sys.modules['pandas.indexes'] = pandas.core.indexes

# %%
with open ('{}/business.pickle'.format(SHARED_FOLDER), 'rb') as f:
    business_df = pickle.load(f)

# %%
business_df.columns
# Out:
# Index(['attributes', 'business_id', 'categories', 'city', 'full_address',
#        'hours', 'id', 'latitude', 'longitude', 'name', 'neighborhoods', 'open',
#        'review_count', 'stars', 'state', 'type'],
#       dtype='object')

# %%
business_df=business_df[business_df.state=='AZ']

# %%
business_df.shape
# Out:
# (32615, 16)

# %%
example_df_cate=business_df
for i in example_df_cate.categories:
    label=0
    for j in i:
        if (j=='Restaurants'):label=1
        elif (j=='Food'):label=1
    i.append(label)

# %%
f=lambda x:x[-1]
example_df_cate['is_restaurant']=example_df_cate.categories.apply(f)

# %%
example_df_cate=example_df_cate[example_df_cate.is_restaurant==1]

del example_df_cate['id']
del example_df_cate['neighborhoods']
del example_df_cate['state']
del example_df_cate['type']
del example_df_cate['is_restaurant']

example_df_cate=example_df_cate.reset_index(drop = True)

del example_df_cate['full_address']
del example_df_cate['name']

example_df_fin=example_df_cate

# %%
example_df_fin
# Out:
#                                               attributes  \
# 0      {'Good For': {'latenight': False, 'dinner': Fa...
# 1      {'Good For': {'latenight': True, 'dinner': Tru...
# 2      {'Good For': {'latenight': False, 'dinner': Fa...
# 3      {'Good For': {'latenight': False, 'dinner': Tr...
# 4      {'Good For': {'latenight': False, 'dinner': Fa...
# 5      {'Drive-Thru': True, 'Price Range': 1, 'Good F...
# 6      {'Price Range': 1, 'Wheelchair Accessible': Tr...
# 7      {'Drive-Thru': True, 'Good For': {'latenight':...
# 8      {'Good For': {'latenight': False, 'dinner': Fa...
# 9      {'By Appointment Only': False, 'Price Range': ...
# 10     {'Drive-Thru': False, 'Wheelchair Accessible':...
# 11     {'Drive-Thru': True, 'Good For': {'latenight':...
# 12     {'Good For': {'latenight': False, 'dinner': Fa...
# 13     {'Good For': {'latenight': False, 'dinner': Fa...
# 14     {'Drive-Thru': False, 'Good For': {'latenight'...
# ...

# %%
example_df_fin.categories[3:10][:-2]
# Out:
# 3                        [Barbeque, Restaurants, 1, 1]
# 4                         [Tex-Mex, Restaurants, 1, 1]
# 5     [Fast Food, Mexican, Tex-Mex, Restaurants, 1, 1]
# 6    [Food, Automotive, Convenience Stores, Gas & S...
# 7                       [Fast Food, Restaurants, 1, 1]
# Name: categories, dtype: object

# %%
L=[]
for i in range(len(example_df_fin.categories)):
    category=example_df_fin.categories[i][:-2][0]
    if ((category not in L) and (category != '')):
        L.append(category)
L
# Out:
# ['Sandwiches',
#  'Pizza',
#  'Vegetarian',
#  'Barbeque',
#  'Tex-Mex',
#  'Fast Food',
#  'Food',
#  'Shopping',
#  'Bars',
#  'Thai',
#  'Burgers',
#  'Breakfast & Brunch',
#  'Chicken Wings',
#  'Mexican',
#  'Sushi Bars',
#  'Restaurants',
#  'Chinese',
#  'Italian',
#  'American (Traditional)',
#  'Nightlife',
#  'Gastropubs',
#  'Fondue',
#  'Seafood',
#  'American (New)',
#  'Arts & Entertainment',
#  'Health Markets',
#  'Steakhouses',
#  'Greek',
#  'Comfort Food',
#  'Delis',
#  'Buffets',
#  'French',
#  'Hot Dogs',
#  'Diners',
#  'Soul Food',
#  'Soup',
#  'Country Dance Halls',
#  'Bakeries',
#  'Specialty Schools',
#  'Japanese',
#  'Latin American',
#  'Pakistani',
#  'Indian',
#  'Cheesesteaks',
#  'Asian Fusion',
#  'Basque',
#  'Wine Bars',
#  'Vietnamese',
#  'Caribbean',
#  'Pubs',
#  'Cafes',
#  'Department Stores',
#  'Gluten-Free',
#  'Event Planning & Services',
#  'Hot Pot',
#  'Middle Eastern',
#  'Korean',
#  'Hawaiian',
#  'Lebanese',
#  'Dive Bars',
# ...

# %%
example_df_fin['categories_Fastfood']=0
example_df_fin['categories_Vegetarian']=0
example_df_fin['categories_Coffee']=0
example_df_fin['categories_Mexican']=0
example_df_fin['categories_Bars']=0

for i in range(0,example_df_fin.shape[0]):
    for j in example_df_fin.categories[i]:
        if (j=='Fast Food'):example_df_fin['categories_Fastfood'][i]=1
        if (j=='Sandwiches'):example_df_fin['categories_Fastfood'][i]=1
        if (j=='Pizza'):example_df_fin['categories_Fastfood'][i]=1
        if (j=='Burgers'):example_df_fin['categories_Fastfood'][i]=1
        if (j=='Hot Dogs'):example_df_fin['categories_Fastfood'][i]=1
        if (j=='Chicken Wings'):example_df_fin['categories_Fastfood'][i]=1
            
        if (j=='Vegetarian'):example_df_fin['categories_Vegetarian'][i]=1
        if (j=='Vegan'):example_df_fin['categories_Vegetarian'][i]=1
        
        if (j=='Tex-Mex'):example_df_fin['categories_Mexican'][i]=1
        if (j=='Mexican'):example_df_fin['categories_Mexican'][i]=1

        if (j=='Coffee & Tea'):example_df_fin['categories_Coffee'][i]=1
        if (j=='Cafes'):example_df_fin['categories_Coffee'][i]=1    

        if (j=='Nightlife'):example_df_fin['categories_Bars'][i]=1 
        if (j=='Bars'):example_df_fin['categories_Bars'][i]=1
        if (j=='Gastropubs'):example_df_fin['categories_Bars'][i]=1
        if (j=='Dive Bars'):example_df_fin['categories_Bars'][i]=1
        if (j=='Wine Bars'):example_df_fin['categories_Bars'][i]=1     
example_df_fin
# Out:
# C:\Users\feelaamr\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\feelaamr\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\feelaamr\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
business_Fastfood.shape

# %%
business_Fastfood=example_df_fin[example_df_fin['categories_Fastfood']==1]
business_Vegetarian=example_df_fin[example_df_fin['categories_Vegetarian']==1]
business_Coffee=example_df_fin[example_df_fin['categories_Coffee']==1]
business_Mexican=example_df_fin[example_df_fin['categories_Mexican']==1]
business_Bars=example_df_fin[example_df_fin['categories_Bars']==1]

# %%
business_Fastfood['attributes.AcceptsCreditCards']=2
business_Fastfood['attributes.AcceptsInsurance']=2
business_Fastfood['attributes.AgesAllowed']='NaN'
business_Fastfood['attributes.Alcohol']=0
business_Fastfood['attributes.Ambience.casual']=2
business_Fastfood['attributes.Ambience.classy']=2
business_Fastfood['attributes.Ambience.divey']=2
business_Fastfood['attributes.Ambience.hipster']=2
business_Fastfood['attributes.Ambience.intimate']=2
business_Fastfood['attributes.Ambience.romantic']=2
business_Fastfood['attributes.Ambience.touristy']=2
business_Fastfood['attributes.Ambience.trendy']=2
business_Fastfood['attributes.Attire']=0
business_Fastfood['attributes.BYOB']=2
business_Fastfood['attributes.BYOB/Corkage']=0
business_Fastfood['attributes.ByAppointmentOnly']=2
business_Fastfood['attributes.Caters']=2
business_Fastfood['attributes.CoatCheck']=2
business_Fastfood['attributes.Corkage']=2
business_Fastfood['attributes.Delivery']=2
business_Fastfood['attributes.DietaryRestrictions.dairyfree']=2
business_Fastfood['attributes.DietaryRestrictions.glutenfree']=2
business_Fastfood['attributes.DietaryRestrictions.halal']=2
business_Fastfood['attributes.DietaryRestrictions.kosher']=2
business_Fastfood['attributes.DietaryRestrictions.soyfree']=2
business_Fastfood['attributes.DietaryRestrictions.vegan']=2
business_Fastfood['attributes.DietaryRestrictions.vegetarian']=2
business_Fastfood['attributes.DogsAllowed']=2
business_Fastfood['attributes.DriveThru']=2
business_Fastfood['attributes.GoodFor.breakfast']=2
business_Fastfood['attributes.GoodFor.brunch']=2
business_Fastfood['attributes.GoodFor.dessert']=2
business_Fastfood['attributes.GoodFor.dinner']=2
business_Fastfood['attributes.GoodFor.latenight']=2
business_Fastfood['attributes.GoodFor.lunch']=2
business_Fastfood['attributes.GoodForDancing']=2
business_Fastfood['attributes.GoodForGroups']=2
business_Fastfood['attributes.GoodForKids']=2
business_Fastfood['attributes.HairTypesSpecializedIn.africanamerican']=2
business_Fastfood['attributes.HairTypesSpecializedIn.asian']=2
business_Fastfood['attributes.HairTypesSpecializedIn.coloring']=2
business_Fastfood['attributes.HairTypesSpecializedIn.curly']=2
business_Fastfood['attributes.HairTypesSpecializedIn.extensions']=2
business_Fastfood['attributes.HairTypesSpecializedIn.kids']=2
business_Fastfood['attributes.HairTypesSpecializedIn.perms']=2
business_Fastfood['attributes.HairTypesSpecializedIn.straightperms']=2
business_Fastfood['attributes.HappyHour']=2
business_Fastfood['attributes.HasTV']=2
business_Fastfood['attributes.Music.background_music']=2
business_Fastfood['attributes.Music.dj']=2
business_Fastfood['attributes.Music.jukebox']=2
business_Fastfood['attributes.Music.karaoke']=2
business_Fastfood['attributes.Music.live']=2
business_Fastfood['attributes.Music.video']=2
business_Fastfood['attributes.NoiseLevel']=0
business_Fastfood['attributes.Open24Hours']=2
business_Fastfood['attributes.OrderatCounter']=2
business_Fastfood['attributes.OutdoorSeating']=2
business_Fastfood['attributes.PriceRange']=0
business_Fastfood['attributes.Smoking']=2
business_Fastfood['attributes.Takeout']=2
business_Fastfood['attributes.TakesReservations']=2
business_Fastfood['attributes.WaiterService']=2
business_Fastfood['attributes.WheelchairAccessible']=2
business_Fastfood['attributes.WiFi']=2
business_Fastfood['attributes.Parking.garage']=2
business_Fastfood['attributes.Parking.lot']=2
business_Fastfood['attributes.Parking.street']=2
business_Fastfood['attributes.Parking.valet']=2
business_Fastfood['attributes.Parking.validated']=2
business_Fastfood['hours.Friday.close']=25
business_Fastfood['hours.Friday.open']=25
business_Fastfood['hours.Monday.close']=25
business_Fastfood['hours.Monday.open']=25
business_Fastfood['hours.Saturday.close']=25
business_Fastfood['hours.Saturday.open']=25
business_Fastfood['hours.Sunday.close']=25
business_Fastfood['hours.Sunday.open']=25
business_Fastfood['hours.Thursday.close']=25
business_Fastfood['hours.Thursday.open']=25
business_Fastfood['hours.Tuesday.close']=25
business_Fastfood['hours.Tuesday.open']=25
business_Fastfood['hours.Wednesday.close']=25
business_Fastfood['hours.Wednesday.open']=25

# %%
for i in range(0,business_Fastfood.shape[0]):
    if 'Friday' in business_Fastfood.hours[i]:
        if 'close'in business_Fastfood.hours[i]['Friday']:
            business_Fastfood['hours.Friday.close'][i]=int(business_Fastfood.hours[i]['Friday']['close'][0:2])
        if 'open'in business_Fastfood.hours[i]['Friday']:
            business_Fastfood['hours.Friday.open'][i]=int(business_Fastfood.hours[i]['Friday']['open'][0:2])
    if 'Monday' in business_Fastfood.hours[i]:
        if 'close'in business_Fastfood.hours[i]['Monday']:
            business_Fastfood['hours.Monday.close'][i]=int(business_Fastfood.hours[i]['Monday']['close'][0:2])
        if 'open'in business_Fastfood.hours[i]['Monday']:
            business_Fastfood['hours.Monday.open'][i]=int(business_Fastfood.hours[i]['Monday']['open'][0:2])
    if 'Saturday' in business_Fastfood.hours[i]:
        if 'close'in business_Fastfood.hours[i]['Saturday']:
            business_Fastfood['hours.Saturday.close'][i]=int(business_Fastfood.hours[i]['Saturday']['close'][0:2])
        if 'open'in business_Fastfood.hours[i]['Saturday']:
            business_Fastfood['hours.Saturday.open'][i]=int(business_Fastfood.hours[i]['Saturday']['open'][0:2])
    if 'Sunday' in business_Fastfood.hours[i]:
        if 'close'in business_Fastfood.hours[i]['Sunday']:
            business_Fastfood['hours.Sunday.close'][i]=int(business_Fastfood.hours[i]['Sunday']['close'][0:2])
        if 'open'in business_Fastfood.hours[i]['Sunday']:
            business_Fastfood['hours.Sunday.open'][i]=int(business_Fastfood.hours[i]['Sunday']['open'][0:2])
    if 'Thursday' in business_Fastfood.hours[i]:
        if 'close'in business_Fastfood.hours[i]['Thursday']:
            business_Fastfood['hours.Thursday.close'][i]=int(business_Fastfood.hours[i]['Thursday']['close'][0:2])
        if 'open'in business_Fastfood.hours[i]['Thursday']:
            business_Fastfood['hours.Thursday.open'][i]=int(business_Fastfood.hours[i]['Thursday']['open'][0:2])
    if 'Tuesday' in business_Fastfood.hours[i]:
        if 'close'in business_Fastfood.hours[i]['Tuesday']:
            business_Fastfood['hours.Tuesday.close'][i]=int(business_Fastfood.hours[i]['Tuesday']['close'][0:2])
        if 'open'in business_Fastfood.hours[i]['Tuesday']:
            business_Fastfood['hours.Tuesday.open'][i]=int(business_Fastfood.hours[i]['Tuesday']['open'][0:2])
    if 'Wednesday' in business_Fastfood.hours[i]:
        if 'close'in business_Fastfood.hours[i]['Wednesday']:
            business_Fastfood['hours.Wednesday.close'][i]=int(business_Fastfood.hours[i]['Wednesday']['close'][0:2])
        if 'open'in business_Fastfood.hours[i]['Wednesday']:
            business_Fastfood['hours.Wednesday.open'][i]=int(business_Fastfood.hours[i]['Wednesday']['open'][0:2])   
    if 'Parking' in business_Fastfood.attributes[i]:
        if 'garage'in business_Fastfood.attributes[i]['Parking']:
            business_Fastfood['attributes.Parking.garage'][i]=int(business_Fastfood.attributes[i]['Parking']['garage'])
        if 'lot'in business_Fastfood.attributes[i]['Parking']:
            business_Fastfood['attributes.Parking.lot'][i]=int(business_Fastfood.attributes[i]['Parking']['lot'])
        if 'valet'in business_Fastfood.attributes[i]['Parking']:
            business_Fastfood['attributes.Parking.valet'][i]=int(business_Fastfood.attributes[i]['Parking']['valet'])
        if 'street'in business_Fastfood.attributes[i]['Parking']:
            business_Fastfood['attributes.Parking.street'][i]=int(business_Fastfood.attributes[i]['Parking']['street'])
        if 'validated'in business_Fastfood.attributes[i]['Parking']:
            business_Fastfood['attributes.Parking.validated'][i]=int(business_Fastfood.attributes[i]['Parking']['validated'])
    if 'Noise Level' in business_Fastfood.attributes[i]:
        if business_Fastfood.attributes[i]['Noise Level']=='quiet':business_Fastfood['attributes.NoiseLevel'][i]=1
        elif business_Fastfood.attributes[i]['Noise Level']=='average':business_Fastfood['attributes.NoiseLevel'][i]=2
        elif business_Fastfood.attributes[i]['Noise Level']=='loud':business_Fastfood['attributes.NoiseLevel'][i]=3
        else:business_Fastfood['attributes.NoiseLevel'][i]=4
    if 'Open 24 Hours' in business_Fastfood.attributes[i]:
        business_Fastfood['attributes.Open24Hours'][i]=int(business_Fastfood.attributes[i]['Open 24 Hours'])
    if 'Order at Counter' in business_Fastfood.attributes[i]:
        business_Fastfood['attributes.OrderatCounter'][i]=int(business_Fastfood.attributes[i]['Order at Counter'])
    if 'Outdoor Seating' in business_Fastfood.attributes[i]:
        business_Fastfood['attributes.OutdoorSeating'][i]=int(business_Fastfood.attributes[i]['Outdoor Seating'])
    if 'Price Range' in business_Fastfood.attributes[i]:
        business_Fastfood['attributes.PriceRange'][i]=business_Fastfood.attributes[i]['Price Range']
    if 'Smoking' in business_Fastfood.attributes[i]:
        if business_Fastfood.attributes[i]['Smoking']=='no':business_Fastfood['attributes.Smoking'][i]=0
        else:business_Fastfood['attributes.Smoking'][i]=1
    if 'Take-out' in business_Fastfood.attributes[i]:
        business_Fastfood['attributes.Takeout'][i]=int(business_Fastfood.attributes[i]['Take-out'])
    if 'Takes Reservations' in business_Fastfood.attributes[i]:
        business_Fastfood['attributes.TakesReservations'][i]=int(business_Fastfood.attributes[i]['Takes Reservations'])
    if 'Waiter Service' in business_Fastfood.attributes[i]:
        business_Fastfood['attributes.WaiterService'][i]=int(business_Fastfood.attributes[i]['Waiter Service'])
    if 'Wheelchair Accessible' in business_Fastfood.attributes[i]:
        business_Fastfood['attributes.WheelchairAccessible'][i]=int(business_Fastfood.attributes[i]['Wheelchair Accessible'])
    if 'Wi-Fi' in business_Fastfood.attributes[i]:
        if business_Fastfood.attributes[i]['Wi-Fi']=='no':business_Fastfood['attributes.WiFi'][i]=0
        elif business_Fastfood.attributes[i]['Wi-Fi']=='free':business_Fastfood['attributes.WiFi'][i]=1
    if 'Music' in business_Fastfood.attributes[i]:
        if 'background_music'in business_Fastfood.attributes[i]['Music']:
            business_Fastfood['attributes.Music.background_music'][i]=int(business_Fastfood.attributes[i]['Music']['background_music'])
        if 'dj'in business_Fastfood.attributes[i]['Music']:
            business_Fastfood['attributes.Music.dj'][i]=int(business_Fastfood.attributes[i]['Music']['dj'])
        if 'jukebox'in business_Fastfood.attributes[i]['Music']:
            business_Fastfood['attributes.Music.jukebox'][i]=int(business_Fastfood.attributes[i]['Music']['jukebox'])
        if 'karaoke'in business_Fastfood.attributes[i]['Music']:
            business_Fastfood['attributes.Music.karaoke'][i]=int(business_Fastfood.attributes[i]['Music']['karaoke'])
        if 'live'in business_Fastfood.attributes[i]['Music']:
            business_Fastfood['attributes.Music.live'][i]=int(business_Fastfood.attributes[i]['Music']['live'])
        if 'video'in business_Fastfood.attributes[i]['Music']:
            business_Fastfood['attributes.Music.video'][i]=int(business_Fastfood.attributes[i]['Music']['video'])
    if 'Happy Hour' in business_Fastfood.attributes[i]:
        business_Fastfood['attributes.HappyHour'][i]=int(business_Fastfood.attributes[i]['Happy Hour'])
    if 'HasTV' in business_Fastfood.attributes[i]:
        business_Fastfood['attributes.HasTV'][i]=int(business_Fastfood.attributes[i]['Has TV'])
    if 'Hair Types Specialized In' in business_Fastfood.attributes[i]:
        if 'africanamerican'in business_Fastfood.attributes[i]['Hair Types Specialized In']:
            business_Fastfood['attributes.HairTypesSpecializedIn.africanamerican'][i]=int(business_Fastfood.attributes[i]['Hair Types Specialized In']['africanamerican'])
        if 'asian'in business_Fastfood.attributes[i]['Hair Types Specialized In']:
            business_Fastfood['attributes.HairTypesSpecializedIn.asian'][i]=int(business_Fastfood.attributes[i]['Hair Types Specialized In']['asian'])
        if 'coloring'in business_Fastfood.attributes[i]['Hair Types Specialized In']:
            business_Fastfood['attributes.HairTypesSpecializedIn.coloring'][i]=int(business_Fastfood.attributes[i]['Hair Types Specialized In']['coloring'])
        if 'curly'in business_Fastfood.attributes[i]['Hair Types Specialized In']:
            business_Fastfood['attributes.HairTypesSpecializedIn.curly'][i]=int(business_Fastfood.attributes[i]['Hair Types Specialized In']['curly'])
        if 'extensions'in business_Fastfood.attributes[i]['Hair Types Specialized In']:
            business_Fastfood['attributes.HairTypesSpecializedIn.extensions'][i]=int(business_Fastfood.attributes[i]['Hair Types Specialized In']['extensions'])
        if 'kids'in business_Fastfood.attributes[i]['Hair Types Specialized In']:
            business_Fastfood['attributes.HairTypesSpecializedIn.kids'][i]=int(business_Fastfood.attributes[i]['Hair Types Specialized In']['kids'])
        if 'perms'in business_Fastfood.attributes[i]['Hair Types Specialized In']:
            business_Fastfood['attributes.HairTypesSpecializedIn.perms'][i]=int(business_Fastfood.attributes[i]['Hair Types Specialized In']['perms'])
        if 'straightperms'in business_Fastfood.attributes[i]['Hair Types Specialized In']:
            business_Fastfood['attributes.HairTypesSpecializedIn.straightperms'][i]=int(business_Fastfood.attributes[i]['Hair Types Specialized In']['straightperms'])
    if 'Good For Dancing' in business_Fastfood.attributes[i]:
        business_Fastfood['attributes.GoodForDancing'][i]=int(business_Fastfood.attributes[i]['Good For Dancing'])
    if 'Good For Groups' in business_Fastfood.attributes[i]:
        business_Fastfood['attributes.GoodForGroups'][i]=int(business_Fastfood.attributes[i]['Good For Groups'])
    if 'Good For Kids' in business_Fastfood.attributes[i]:
        business_Fastfood['attributes.GoodForKids'][i]=int(business_Fastfood.attributes[i]['Good For Kids'])
    if 'Good For' in business_Fastfood.attributes[i]:
        if 'breakfast'in business_Fastfood.attributes[i]['Good For']:
            business_Fastfood['attributes.GoodFor.breakfast'][i]=int(business_Fastfood.attributes[i]['Good For']['breakfast'])
        if 'brunch'in business_Fastfood.attributes[i]['Good For']:
            business_Fastfood['attributes.GoodFor.brunch'][i]=int(business_Fastfood.attributes[i]['Good For']['brunch'])
        if 'dessert'in business_Fastfood.attributes[i]['Good For']:
            business_Fastfood['attributes.GoodFor.dessert'][i]=int(business_Fastfood.attributes[i]['Good For']['dessert'])
        if 'dinner'in business_Fastfood.attributes[i]['Good For']:
            business_Fastfood['attributes.GoodFor.dinner'][i]=int(business_Fastfood.attributes[i]['Good For']['dinner'])
        if 'latenight'in business_Fastfood.attributes[i]['Good For']:
            business_Fastfood['attributes.GoodFor.latenight'][i]=int(business_Fastfood.attributes[i]['Good For']['latenight'])
        if 'lunch'in business_Fastfood.attributes[i]['Good For']:
            business_Fastfood['attributes.GoodFor.lunch'][i]=int(business_Fastfood.attributes[i]['Good For']['lunch'])
    if 'Dogs Allowed' in business_Fastfood.attributes[i]:
        business_Fastfood['attributes.DogsAllowed'][i]=int(business_Fastfood.attributes[i]['Dogs Allowed'])
    if 'Drive-Thru' in business_Fastfood.attributes[i]:
        business_Fastfood['attributes.DriveThru'][i]=int(business_Fastfood.attributes[i]['Drive-Thru'])
    if 'Dietary Restrictions' in business_Fastfood.attributes[i]:
        if 'dairy-free'in business_Fastfood.attributes[i]['Dietary Restrictions']:
            business_Fastfood['attributes.DietaryRestrictions.dairyfree'][i]=int(business_Fastfood.attributes[i]['Dietary Restrictions']['dairy-free'])
        if 'gluten-free'in business_Fastfood.attributes[i]['Dietary Restrictions']:
            business_Fastfood['attributes.DietaryRestrictions.glutenfree'][i]=int(business_Fastfood.attributes[i]['Dietary Restrictions']['gluten-free'])
        if 'halal'in business_Fastfood.attributes[i]['Dietary Restrictions']:
            business_Fastfood['attributes.DietaryRestrictions.halal'][i]=int(business_Fastfood.attributes[i]['Dietary Restrictions']['halal'])
        if 'kosher'in business_Fastfood.attributes[i]['Dietary Restrictions']:
            business_Fastfood['attributes.DietaryRestrictions.kosher'][i]=int(business_Fastfood.attributes[i]['Dietary Restrictions']['kosher'])
        if 'soy-free'in business_Fastfood.attributes[i]['Dietary Restrictions']:
            business_Fastfood['attributes.DietaryRestrictions.soyfree'][i]=int(business_Fastfood.attributes[i]['Dietary Restrictions']['soy-free'])
        if 'vegan'in business_Fastfood.attributes[i]['Dietary Restrictions']:
            business_Fastfood['attributes.DietaryRestrictions.vegan'][i]=int(business_Fastfood.attributes[i]['Dietary Restrictions']['vegan'])
        if 'vegetarian'in business_Fastfood.attributes[i]['Dietary Restrictions']:
            business_Fastfood['attributes.DietaryRestrictions.vegetarian'][i]=int(business_Fastfood.attributes[i]['Dietary Restrictions']['vegetarian'])
    if 'Attire' in business_Fastfood.attributes[i]:
        if business_Fastfood.attributes[i]['Attire']=='casual':business_Fastfood['attributes.Attire'][i]=1
        else:business_Fastfood['attributes.Attire'][i]=2
    if 'BYOB' in business_Fastfood.attributes[i]:
        business_Fastfood['attributes.BYOB'][i]=int(business_Fastfood.attributes[i]['BYOB'])
    if 'BYOB/Corkage' in business_Fastfood.attributes[i]:
        if business_Fastfood.attributes[i]['BYOB/Corkage']=='no':business_Fastfood['attributes.BYOB/Corkage'][i]=1
        else:business_Fastfood['attributes.BYOB/Corkage'][i]=2
    if 'By Appointment Only' in business_Fastfood.attributes[i]:
        business_Fastfood['attributes.ByAppointmentOnly'][i]=int(business_Fastfood.attributes[i]['By Appointment Only'])
    if 'Caters' in business_Fastfood.attributes[i]:
        business_Fastfood['attributes.Caters'][i]=int(business_Fastfood.attributes[i]['Caters'])
    if 'Coat Check' in business_Fastfood.attributes[i]:
        business_Fastfood['attributes.CoatCheck'][i]=int(business_Fastfood.attributes[i]['Coat Check'])
    if 'Corkage' in business_Fastfood.attributes[i]:
        business_Fastfood['attributes.Corkage'][i]=int(business_Fastfood.attributes[i]['Corkage'])
    if 'Delivery' in business_Fastfood.attributes[i]:
        business_Fastfood['attributes.Delivery'][i]=int(business_Fastfood.attributes[i]['Delivery'])
    if 'Ambience' in business_Fastfood.attributes[i]:
        if 'casual'in business_Fastfood.attributes[i]['Ambience']:
            business_Fastfood['attributes.Ambience.casual'][i]=int(business_Fastfood.attributes[i]['Ambience']['casual'])
        if 'classy'in business_Fastfood.attributes[i]['Ambience']:
            business_Fastfood['attributes.Ambience.classy'][i]=int(business_Fastfood.attributes[i]['Ambience']['classy'])
        if 'divey'in business_Fastfood.attributes[i]['Ambience']:
            business_Fastfood['attributes.Ambience.divey'][i]=int(business_Fastfood.attributes[i]['Ambience']['divey'])
        if 'hipster'in business_Fastfood.attributes[i]['Ambience']:
            business_Fastfood['attributes.Ambience.hipster'][i]=int(business_Fastfood.attributes[i]['Ambience']['hipster'])
        if 'intimate'in business_Fastfood.attributes[i]['Ambience']:
            business_Fastfood['attributes.Ambience.intimate'][i]=int(business_Fastfood.attributes[i]['Ambience']['intimate'])
        if 'romantic'in business_Fastfood.attributes[i]['Ambience']:
            business_Fastfood['attributes.Ambience.romantic'][i]=int(business_Fastfood.attributes[i]['Ambience']['romantic'])
        if 'touristy'in business_Fastfood.attributes[i]['Ambience']:
            business_Fastfood['attributes.Ambience.touristy'][i]=int(business_Fastfood.attributes[i]['Ambience']['touristy'])
        if 'trendy'in business_Fastfood.attributes[i]['Ambience']:
            business_Fastfood['attributes.Ambience.trendy'][i]=int(business_Fastfood.attributes[i]['Ambience']['trendy'])
    if 'Accepts Insurance' in business_Fastfood.attributes[i]:
        business_Fastfood['attributes.AcceptsInsurance'][i]=int(business_Fastfood.attributes[i]['Accepts Insurance'])
    if 'Ages Allowed' in business_Fastfood.attributes[i]:
        business_Fastfood['attributes.AgesAllowed'][i]=business_Fastfood.attributes[i]['Ages Allowed']
    if 'Alcohol' in business_Fastfood.attributes[i]:
        if business_Fastfood.attributes[i]['Alcohol']=='none':business_Fastfood['attributes.Alcohol'][i]=1
        elif business_Fastfood.attributes[i]['Alcohol']=='full_bar':business_Fastfood['attributes.Alcohol'][i]=2
        elif business_Fastfood.attributes[i]['Alcohol']=='beer_and_wine':business_Fastfood['attributes.Alcohol'][i]=3
        else: business_Fastfood['attributes.Alcohol'][i]=4       
    if 'Accepts Credit Cards' in business_Fastfood.attributes[i]:
        business_Fastfood['attributes.AcceptsCreditCards'][i]=int(business_Fastfood.attributes[i]['Accepts Credit Cards'])

# %%
del example_df_fin['attributes.AgesAllowed']

# %%
business_df.stars.value_counts().sort_values()

# %%
# %matplotlib inline
#importation de la librairie
import matplotlib.pyplot as plt

# %%
business_df.hist(column='stars')

# %%
business_df['stars'].plot.kde()

# %%
business_df.hist(column='review_count')
