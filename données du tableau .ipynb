# %%
import pickle
import pandas as pd 
import numpy as np 
# Shared folder to read data
SHARED_FOLDER = './yelp'

# Your folder to write new data and create notebooks.
MY_FOLDER = './output'

# %% [markdown]
# # add a single category to business

# %%
with open ('{}/new_business.pickle'.format(SHARED_FOLDER), 'rb') as f:
    business_df = pickle.load(f)

# %%
business_df
# Out:
#                                              attributes  \
# 0     {'Ambience': {'intimate': False, 'romantic': F...
# 1     {'Dogs Allowed': True, 'Ambience': {'intimate'...
# 2     {'Wheelchair Accessible': True, 'Attire': 'cas...
# 3     {'Alcohol': 'none', 'Outdoor Seating': True, '...
# 4     {'Alcohol': 'none', 'Outdoor Seating': True, '...
# 5     {'Parking': {'lot': True, 'garage': False, 'va...
# 6     {'Noise Level': 'average', 'Wheelchair Accessi...
# 7     {'Wheelchair Accessible': True, 'Attire': 'cas...
# 8     {'Parking': {'lot': True, 'garage': False, 'va...
# 9     {'Good for Kids': True, 'Good For': {'breakfas...
# 10    {'Alcohol': 'none', 'Outdoor Seating': False, ...
# 11    {'Noise Level': 'average', 'Wheelchair Accessi...
# 12    {'Dogs Allowed': True, 'Alcohol': 'full_bar', ...
# 13    {'Alcohol': 'none', 'Outdoor Seating': False, ...
# 14    {'Alcohol': 'beer_and_wine', 'Has TV': True, '...
# 15    {'Alcohol': 'none', 'Outdoor Seating': False, ...
# ...

# %%
business_df.to_csv('./output/business_df.csv')

# %%
with open ('{}/categories.pickle'.format(SHARED_FOLDER), 'rb') as f:
     categories_df = pickle.load(f)

# %%
business_categories_df = business_df.merge(categories_df, on='business_id', how='left',
                                         suffixes=['business','categories'])
business_categories_df
# Out:
#                                              attributes  \
# 0     {'Ambience': {'intimate': False, 'romantic': F...
# 1     {'Ambience': {'intimate': False, 'romantic': F...
# 2     {'Dogs Allowed': True, 'Ambience': {'intimate'...
# 3     {'Dogs Allowed': True, 'Ambience': {'intimate'...
# 4     {'Dogs Allowed': True, 'Ambience': {'intimate'...
# 5     {'Dogs Allowed': True, 'Ambience': {'intimate'...
# 6     {'Wheelchair Accessible': True, 'Attire': 'cas...
# 7     {'Wheelchair Accessible': True, 'Attire': 'cas...
# 8     {'Alcohol': 'none', 'Outdoor Seating': True, '...
# 9     {'Alcohol': 'none', 'Outdoor Seating': True, '...
# 10    {'Alcohol': 'none', 'Outdoor Seating': True, '...
# 11    {'Alcohol': 'none', 'Outdoor Seating': True, '...
# 12    {'Alcohol': 'none', 'Outdoor Seating': True, '...
# 13    {'Alcohol': 'none', 'Outdoor Seating': True, '...
# 14    {'Parking': {'lot': True, 'garage': False, 'va...
# 15    {'Parking': {'lot': True, 'garage': False, 'va...
# ...

# %%
business_categories_df.to_csv('./output/business_categories_df.csv')

# %% [markdown]
# # category en 5 type

# %%
def five_cate(x):
    if (x=='Fast Food'or x=='Pizza'or x=='Chicken Wings'or x=='Sandwiches'or x=='Burgers'or x=='Hot Dogs'):
        x='Fast Food'
    if (x=='Vegetarian'or x=='Vegan'):
        x='Vegeterian'
    if (x=='Coffee & Tea'or x=='Cafes'):
        x='coffee'
    if (x=='Mexican'or x=='Tex-Mex'):
        x='mexican'
    if (x=='Nighlife'or x=='Bars'or x=='Gastropubs'or x=='Dive Bars'or x=='Wine Bars'or x=='Hot Dogs'):
        x='bars'
    return(x)

# %%
business_categories_df['category'].apply(five_cate)
# Out:
# 0                       Fast Food
# 1                     Restaurants
# 2                      Vegeterian
# 3                          Diners
# 4                      Vegeterian
# 5                     Restaurants
# 6                        Barbeque
# 7                     Restaurants
# 8                         mexican
# 9                     Restaurants
# 10                      Fast Food
# 11                        mexican
# 12                        mexican
# 13                    Restaurants
# 14                           Food
# 15                     Automotive
# 16             Convenience Stores
# 17         Gas & Service Stations
# 18                      Fast Food
# 19                    Restaurants
# 20                           Food
# 21                         coffee
# 22                       Shopping
# 23                     Drugstores
# 24                  Beauty & Spas
# 25                           Food
# 26             Convenience Stores
# ...

# %%
business_categories_df['category1']=business_categories_df['category'].apply(five_cate)

# %%
business_categories_df
# Out:
#                                              attributes  \
# 0     {'Take-out': True, 'Waiter Service': False, 'G...
# 1     {'Take-out': True, 'Waiter Service': False, 'G...
# 2     {'Dogs Allowed': True, 'Attire': 'casual', 'Wa...
# 3     {'Dogs Allowed': True, 'Attire': 'casual', 'Wa...
# 4     {'Dogs Allowed': True, 'Attire': 'casual', 'Wa...
# 5     {'Dogs Allowed': True, 'Attire': 'casual', 'Wa...
# 6     {'Take-out': True, 'Waiter Service': True, 'Go...
# 7     {'Take-out': True, 'Waiter Service': True, 'Go...
# 8     {'Take-out': True, 'Waiter Service': False, 'G...
# 9     {'Take-out': True, 'Waiter Service': False, 'G...
# 10    {'Take-out': True, 'Waiter Service': False, 'G...
# 11    {'Take-out': True, 'Waiter Service': False, 'G...
# 12    {'Take-out': True, 'Waiter Service': False, 'G...
# 13    {'Take-out': True, 'Waiter Service': False, 'G...
# 14    {'Parking': {'validated': False, 'valet': Fals...
# 15    {'Parking': {'validated': False, 'valet': Fals...
# ...

# %%
business_categories_df.to_csv('./output/business_new_categories_df.csv')

# %%
category_fastfood=business_categories_df[business_categories_df['category1']=='Fast Food']
category_fastfood
# Out:
#                                              attributes  \
# 0     {'Take-out': True, 'Waiter Service': False, 'G...
# 10    {'Take-out': True, 'Waiter Service': False, 'G...
# 18    {'Drive-Thru': True, 'Parking': {'validated': ...
# 34    {'Take-out': True, 'Waiter Service': True, 'Go...
# 38    {'Dogs Allowed': True, 'Take-out': True, 'Wait...
# 45    {'Take-out': True, 'Waiter Service': False, 'G...
# 52    {'Music': {'dj': False}, 'Take-out': True, 'Wa...
# 59    {'Drive-Thru': True, 'Parking': {'validated': ...
# 66    {'Take-out': True, 'Waiter Service': False, 'G...
# 71    {'Accepts Credit Cards': True, 'Good For': {'d...
# 81    {'Parking': {'validated': False, 'valet': Fals...
# 82    {'Parking': {'validated': False, 'valet': Fals...
# 84    {'Drive-Thru': False, 'Parking': {'validated':...
# 87    {'Take-out': True, 'Waiter Service': False, 'G...
# 93    {'Parking': {'validated': False, 'valet': Fals...
# 123   {'Drive-Thru': False, 'Parking': {'validated':...
# ...

# %%
category_fastfood.to_csv('./output/category_fastfood.csv')

# %%
category_Vegeterian=business_categories_df[business_categories_df['category1']=='Vegeterian']
category_Vegeterian.to_csv('./output/category_Vegeterian.csv')
category_Vegeterian
# Out:
#                                              attributes  \
# 2     {'Dogs Allowed': True, 'Attire': 'casual', 'Wa...
# 4     {'Dogs Allowed': True, 'Attire': 'casual', 'Wa...
# 607   {'Take-out': True, 'Waiter Service': True, 'Go...
# 612   {'Parking': {'validated': False, 'valet': Fals...
# 797   {'Dogs Allowed': False, 'Attire': 'casual', 'W...
# 1151  {'Take-out': True, 'Good for Kids': True, 'Amb...
# 1626  {'Dogs Allowed': True, 'Attire': 'casual', 'Wa...
# 2087  {'Dogs Allowed': True, 'Take-out': True, 'Wait...
# 2089  {'Dogs Allowed': True, 'Take-out': True, 'Wait...
# 2111  {'Parking': {'validated': False, 'valet': Fals...
# 2431  {'Take-out': True, 'Waiter Service': True, 'Go...
# 2706  {'Take-out': True, 'Waiter Service': True, 'Am...
# 2798  {'Parking': {'validated': False, 'valet': Fals...
# 3087  {'Take-out': True, 'Waiter Service': False, 'G...
# 3089  {'Take-out': True, 'Waiter Service': False, 'G...
# 3350  {'Parking': {'validated': False, 'valet': Fals...
# ...

# %%
category_coffee=business_categories_df[business_categories_df['category1']=='coffee']
category_Vegeterian.to_csv('./output/category_coffee.csv')
category_coffee
# Out:
#                                              attributes  \
# 21    {'Take-out': True, 'Waiter Service': False, 'G...
# 78    {'Take-out': True, 'Waiter Service': True, 'Go...
# 179   {'Accepts Credit Cards': True, 'Wi-Fi': 'free'...
# 213   {'Accepts Credit Cards': True, 'Wi-Fi': 'free'...
# 318   {'Accepts Credit Cards': True, 'Wi-Fi': 'free'...
# 332   {'Accepts Credit Cards': True, 'Wi-Fi': 'free'...
# 335   {'Accepts Credit Cards': True, 'Wi-Fi': 'no', ...
# 339   {'Take-out': True, 'Waiter Service': False, 'G...
# 436   {'Accepts Credit Cards': True, 'Wi-Fi': 'free'...
# 477   {'Accepts Credit Cards': True, 'Outdoor Seatin...
# 488   {'Accepts Credit Cards': True, 'Wi-Fi': 'free'...
# 506   {'Parking': {'validated': False, 'valet': Fals...
# 520   {'Drive-Thru': True, 'Attire': 'casual', 'Wait...
# 561   {'Accepts Credit Cards': True, 'Wi-Fi': 'free'...
# 570   {'Dogs Allowed': False, 'Attire': 'casual', 'W...
# 587   {'Take-out': True, 'Waiter Service': False, 'G...
# ...

# %%
category_mexican=business_categories_df[business_categories_df['category1']=='mexican']
category_mexican.to_csv('./output/category_mexican.csv')
category_mexican
# Out:
#                                              attributes  \
# 8     {'Take-out': True, 'Waiter Service': False, 'G...
# 11    {'Take-out': True, 'Waiter Service': False, 'G...
# 12    {'Take-out': True, 'Waiter Service': False, 'G...
# 47    {'Take-out': True, 'Waiter Service': True, 'Go...
# 55    {'Take-out': True, 'Waiter Service': True, 'Go...
# 88    {'Take-out': True, 'Waiter Service': False, 'G...
# 89    {'Take-out': True, 'Waiter Service': False, 'G...
# 136   {'Parking': {'validated': False, 'valet': Fals...
# 139   {'Dogs Allowed': False, 'Attire': 'casual', 'W...
# 191   {'Dogs Allowed': False, 'Attire': 'casual', 'W...
# 201   {'Parking': {'validated': False, 'valet': Fals...
# 202   {'Parking': {'validated': False, 'valet': Fals...
# 214   {'Take-out': True, 'Waiter Service': False, 'G...
# 216   {'Drive-Thru': False, 'Parking': {'validated':...
# 257   {'Parking': {'validated': False, 'valet': Fals...
# 273   {'Drive-Thru': False, 'Take-out': True, 'Waite...
# ...

# %%
category_bars=business_categories_df[business_categories_df['category1']=='bars']
category_bars.to_csv('./output/category_bars.csv')
category_bars
# Out:
#                                              attributes  \
# 28    {'Music': {'dj': False}, 'Take-out': True, 'Wa...
# 98    {'Music': {'dj': False, 'background_music': Tr...
# 100   {'Music': {'dj': False, 'background_music': Tr...
# 142   {'Music': {'dj': True}, 'Take-out': True, 'Wai...
# 143   {'Music': {'dj': True}, 'Take-out': True, 'Wai...
# 207   {'Parking': {'validated': False, 'valet': Fals...
# 245   {'Music': {'dj': False, 'background_music': Fa...
# 260   {'Music': {'dj': False, 'jukebox': False, 'vid...
# 266   {'Music': {'dj': False}, 'Take-out': True, 'Wa...
# 398   {'Good for Kids': False, 'By Appointment Only'...
# 402   {'Good for Kids': False, 'By Appointment Only'...
# 420   {'Music': {'dj': False, 'jukebox': False, 'vid...
# 440   {'Take-out': True, 'Waiter Service': True, 'Am...
# 495   {'Music': {'dj': False, 'background_music': Fa...
# 512   {'Good for Kids': False, 'By Appointment Only'...
# 515   {'Good for Kids': False, 'By Appointment Only'...
# ...
