# %%
import pickle
import pandas as pd 
import numpy as np 
# Shared folder to read data
SHARED_FOLDER = './yelp'

# Your folder to write new data and create notebooks.
MY_FOLDER = './output'

# %% [markdown]
# # add a single category to business

# %%
with open ('{}/new_more_business.pickle'.format(MY_FOLDER), 'rb') as f:
    business_df = pickle.load(f)

# %%
business_df
# Out:
#                                              attributes  \
# 0     {'Good For': {'dessert': False, 'latenight': T...
# 1     {'Good For': {'dessert': False, 'latenight': F...
# 2     {'Good For': {'dessert': False, 'latenight': F...
# 3     {'Good For': {'dessert': False, 'latenight': F...
# 4     {'Caters': False, 'Take-out': True, 'Waiter Se...
# 5     {'Accepts Credit Cards': True, 'Parking': {'va...
# 6     {'Good For': {'dessert': False, 'latenight': F...
# 7     {'Good For': {'dessert': False, 'latenight': F...
# 8     {'Price Range': 2, 'Wheelchair Accessible': Tr...
# 9     {'Good For': {'dessert': False, 'latenight': T...
# 10    {'Caters': False, 'Good For': {'dessert': Fals...
# 11    {'Good For': {'dessert': False, 'latenight': F...
# 12    {'Good For': {'dessert': False, 'latenight': F...
# 13    {'Good For': {'dessert': False, 'latenight': F...
# 14    {'Good For': {'dessert': False, 'latenight': F...
# 15    {'Good For': {'dessert': False, 'latenight': F...
# ...

# %%
sum(business_df['reviews_count'])
sum(business_df['tip_count'])
# Out:
# 166352

# %%
with open ('{}/categories.pickle'.format(SHARED_FOLDER), 'rb') as f:
     categories_df = pickle.load(f)

# %%
business_categories_df = business_df.merge(categories_df, on='business_id', how='left',
                                         suffixes=['business','categories'])
business_categories_df
# Out:
#                                               attributes  \
# 0      {'Good For': {'dessert': False, 'latenight': T...
# 1      {'Good For': {'dessert': False, 'latenight': T...
# 2      {'Good For': {'dessert': False, 'latenight': F...
# 3      {'Good For': {'dessert': False, 'latenight': F...
# 4      {'Good For': {'dessert': False, 'latenight': F...
# 5      {'Good For': {'dessert': False, 'latenight': F...
# 6      {'Good For': {'dessert': False, 'latenight': F...
# 7      {'Good For': {'dessert': False, 'latenight': F...
# 8      {'Good For': {'dessert': False, 'latenight': F...
# 9      {'Good For': {'dessert': False, 'latenight': F...
# 10     {'Caters': False, 'Take-out': True, 'Waiter Se...
# 11     {'Caters': False, 'Take-out': True, 'Waiter Se...
# 12     {'Caters': False, 'Take-out': True, 'Waiter Se...
# 13     {'Caters': False, 'Take-out': True, 'Waiter Se...
# 14     {'Accepts Credit Cards': True, 'Parking': {'va...
# ...

# %%
business_categories_df.to_csv('./output/new_business_categories_df.csv')

# %% [markdown]
# # category en 5 type

# %%
def five_cate(x):
    if (x=='Fast Food'or x=='Pizza'or x=='Chicken Wings'or x=='Sandwiches'or x=='Burgers'or x=='Hot Dogs'):
        x='Fast Food'
    if (x=='Vegetarian'or x=='Vegan'):
        x='Vegeterian'
    if (x=='Coffee & Tea'or x=='Cafes'):
        x='coffee'
    if (x=='Mexican'or x=='Tex-Mex'):
        x='mexican'
    if (x=='Nighlife'or x=='Bars'or x=='Gastropubs'or x=='Dive Bars'or x=='Wine Bars'or x=='Hot Dogs'):
        x='bars'
    return(x)

# %%
business_categories_df['category'].apply(five_cate)
# Out:
# 0                        Fast Food
# 1                      Restaurants
# 2                       Vegeterian
# 3                           Diners
# 4                       Vegeterian
# 5                      Restaurants
# 6                         Barbeque
# 7                      Restaurants
# 8                          mexican
# 9                      Restaurants
# 10                       Fast Food
# 11                         mexican
# 12                         mexican
# 13                     Restaurants
# 14                            Food
# 15                      Automotive
# 16              Convenience Stores
# 17          Gas & Service Stations
# 18                       Fast Food
# 19                     Restaurants
# 20                            Food
# 21                          coffee
# 22                        Shopping
# 23                      Drugstores
# 24                   Beauty & Spas
# 25                            Food
# 26              Convenience Stores
# ...

# %%
business_categories_df['category1']=business_categories_df['category'].apply(five_cate)

# %%
business_categories_df
# Out:
#                                               attributes  \
# 0      {'Good For': {'dessert': False, 'latenight': T...
# 1      {'Good For': {'dessert': False, 'latenight': T...
# 2      {'Good For': {'dessert': False, 'latenight': F...
# 3      {'Good For': {'dessert': False, 'latenight': F...
# 4      {'Good For': {'dessert': False, 'latenight': F...
# 5      {'Good For': {'dessert': False, 'latenight': F...
# 6      {'Good For': {'dessert': False, 'latenight': F...
# 7      {'Good For': {'dessert': False, 'latenight': F...
# 8      {'Good For': {'dessert': False, 'latenight': F...
# 9      {'Good For': {'dessert': False, 'latenight': F...
# 10     {'Caters': False, 'Take-out': True, 'Waiter Se...
# 11     {'Caters': False, 'Take-out': True, 'Waiter Se...
# 12     {'Caters': False, 'Take-out': True, 'Waiter Se...
# 13     {'Caters': False, 'Take-out': True, 'Waiter Se...
# 14     {'Accepts Credit Cards': True, 'Parking': {'va...
# ...

# %%
business_categories_df.to_csv('./output/business_address_categories_df.csv')

# %% [markdown]
# # fast food->bon et mauvias

# %%
category_fastfood=business_categories_df[business_categories_df['category1']=='Fast Food']
category_fastfood
# Out:
#                                               attributes  \
# 0      {'Good For': {'dessert': False, 'latenight': T...
# 10     {'Caters': False, 'Take-out': True, 'Waiter Se...
# 18     {'Good For': {'dessert': False, 'latenight': F...
# 34     {'Caters': False, 'Good For': {'dessert': Fals...
# 38     {'Good For': {'dessert': False, 'latenight': F...
# 45     {'Good For': {'dessert': False, 'latenight': F...
# 52     {'Good For': {'dessert': False, 'latenight': F...
# 59     {'Good For': {'dessert': False, 'latenight': F...
# 66     {'Good For': {'dessert': False, 'latenight': F...
# 71     {'Good For': {'dessert': False, 'latenight': F...
# 81     {'Good For': {'dessert': False, 'latenight': F...
# 82     {'Good For': {'dessert': False, 'latenight': F...
# 84     {'Good For': {'dessert': False, 'latenight': F...
# 87     {'Take-out': True, 'Waiter Service': False, 'T...
# 93     {'Good For': {'dessert': False, 'latenight': F...
# ...

# %%
mean=np.mean(category_fastfood.stars)
def label_df(x):
    if x<=mean:x=0
    elif x>mean:x=1
    return(x)

# %%
category_fastfood['labels']=category_fastfood['stars'].apply(label_df)
# Out:
# Exception ignored in: <bound method DMatrix.__del__ of <xgboost.core.DMatrix object at 0x000001DFCCCCB358>>
# Traceback (most recent call last):
#   File "C:\Users\18791\Anaconda3\lib\site-packages\xgboost\core.py", line 368, in __del__
#     if self.handle is not None:
# AttributeError: 'DMatrix' object has no attribute 'handle'
# C:\Users\18791\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
features = list(category_fastfood.columns[6:99])
X = category_fastfood[features]
del X['stars']
#del X['category']
#del X['category1']
del X['name']
del X['avg_review_stars']
y=category_fastfood['labels']
#del X['reviews_count']
#del X['avg_review_stars']
from xgboost.sklearn import XGBClassifier
from sklearn import cross_validation, metrics
def do_metrics(y_test,y_pred):
    print ("metrics.accuracy_score:")
    print (metrics.accuracy_score(y_test, y_pred))
    print ("metrics.confusion_matrix:")
    print (metrics.confusion_matrix(y_test, y_pred))
    print ("metrics.precision_score:")
    print (metrics.precision_score(y_test, y_pred))
    print ("metrics.recall_score:")
    print (metrics.recall_score(y_test, y_pred))
    print ("metrics.f1_score:")
    print (metrics.f1_score(y_test,y_pred))
X_train, X_test, y_train, y_test = cross_validation.train_test_split(X, y, test_size=0.3, random_state=0)
model = XGBClassifier(max_depth=5, learning_rate=0.01, n_estimators=160, silent=True, objective='binary:logistic')
model.fit(X_train, y_train)
ans = model.predict(X_test)
do_metrics(y_test, ans)
# Out:
# metrics.accuracy_score:
# 0.757155247181
# metrics.confusion_matrix:
# [[459 131]
#  [149 414]]
# metrics.precision_score:
# 0.759633027523
# metrics.recall_score:
# 0.735346358792
# metrics.f1_score:
# 0.747292418773

# %%
from matplotlib import pylab as plt
labels = [ 'mauvais restaurant','bon restaurant']
cm = metrics.confusion_matrix(y_test, ans)

def plot_cm(cm, labels):
    
    # Compute percentanges
    percent = (cm*100.0)/np.array(np.matrix(cm.sum(axis=1)).T)  # Derp, I'm sure there's a better way
    
    print ('Confusion Matrix Stats')
    for i, label_i in enumerate(labels):
        for j, label_j in enumerate(labels):
            print ("%s/%s: %.2f%% (%d/%d)" % (label_i, label_j, (percent[i][j]), cm[i][j], cm[i].sum()))

    # Show confusion matrix
    # Thanks kermit666 from stackoverflow :)
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.grid(b=False)
    cax = ax.matshow(percent, cmap='Greens')
    plt.title('matrice de confusion du modèle')
    fig.colorbar(cax)
    ax.set_xticklabels([''] + labels)
    ax.set_yticklabels([''] + labels)
    plt.xlabel('Predicted ')
    plt.ylabel('True')
    plt.show()

plot_cm(cm, labels)
# Out:
# Exception ignored in: <bound method DMatrix.__del__ of <xgboost.core.DMatrix object at 0x000001DFBE0D0FD0>>
# Traceback (most recent call last):
#   File "C:\Users\18791\Anaconda3\lib\site-packages\xgboost\core.py", line 368, in __del__
#     if self.handle is not None:
# AttributeError: 'DMatrix' object has no attribute 'handle'
# Confusion Matrix Stats
# mauvais restaurant/mauvais restaurant: 77.80% (459/590)
# mauvais restaurant/bon restaurant: 22.20% (131/590)
# bon restaurant/mauvais restaurant: 26.47% (149/563)
# bon restaurant/bon restaurant: 73.53% (414/563)

# %%
labels = [ 'mauvais restaurant','bon restaurant']
def plot_confusion_matrix(y_true, y_pred, labels):
    import matplotlib.pyplot as plt
    from sklearn.metrics import confusion_matrix
    #cmap = plt.cm.binary
    cmap='Blues'
    cm = confusion_matrix(y_true, y_pred)
    tick_marks = np.array(range(len(labels))) + 0.5
    np.set_printoptions(precision=2)
    cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    plt.figure(figsize=(5, 4), dpi=120)
    ind_array = np.arange(len(labels))
    x, y = np.meshgrid(ind_array, ind_array)
    intFlag = 0 
    for x_val, y_val in zip(x.flatten(), y.flatten()):
        if (intFlag):
            c = cm[y_val][x_val]
            plt.text(x_val, y_val, "%d" % (c,), color='red', fontsize=8, va='center', ha='center')

        else:
            c = cm_normalized[y_val][x_val]
            if (c > 0.01):
                #add numbers
                plt.text(x_val, y_val, "%0.2f" % (c,), color='red', fontsize=7, va='center', ha='center')
            else:
                plt.text(x_val, y_val, "%d" % (0,), color='red', fontsize=7, va='center', ha='center')
    if(intFlag):
        plt.imshow(cm, interpolation='nearest', cmap=cmap)
    else:
        plt.imshow(cm_normalized, interpolation='nearest', cmap=cmap)

    plt.gca().set_xticks(tick_marks, minor=False)
    plt.gca().set_yticks(tick_marks, minor=True)
    plt.gca().xaxis.set_ticks_position('none')
    plt.gca().yaxis.set_ticks_position('none')
    plt.gca().xaxis.tick_top()
    plt.grid(True, which='minor', linestyle='-')
    plt.gcf().subplots_adjust(bottom=0.15)
    plt.colorbar()
    xlocations = np.array(range(len(labels)))
    plt.xticks(xlocations, labels)
    plt.yticks(xlocations, labels)
    plt.title('matrice de confusion du modèle\n')
    plt.ylabel('True Classes')
    plt.xlabel('Predict Classes')
    plt.savefig('confusion_matrix.jpg', dpi=300)
    plt.show()
plot_confusion_matrix(y_test, ans,labels)

# %%
bon_category_fastfood=category_fastfood[category_fastfood['labels']==1]
bon_category_fastfood.to_csv('./output/bon_category_fastfood.csv')

# %%
mauvais_category_fastfood=category_fastfood[category_fastfood['labels']==0]
mauvais_category_fastfood.to_csv('./output/mauvais_category_fastfood.csv')

# %% [markdown]
# # Vegeterian

# %%
category_Vegeterian=business_categories_df[business_categories_df['category1']=='Vegeterian']
mean=np.mean(category_Vegeterian.stars)
category_Vegeterian['labels']=category_Vegeterian['stars'].apply(label_df)
bon_category_Vegeterian=category_Vegeterian[category_Vegeterian['labels']==1]
bon_category_Vegeterian.to_csv('./output/bon_category_Vegeterian.csv')
mauvais_category_Vegeterian=category_Vegeterian[category_Vegeterian['labels']==0]
mauvais_category_Vegeterian.to_csv('./output/mauvais_category_Vegeterian.csv')
# Out:
# C:\Users\18791\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %% [markdown]
# # coffee

# %%
category_coffee=business_categories_df[business_categories_df['category1']=='coffee']
mean=np.mean(category_coffee.stars)
category_coffee['labels']=category_coffee['stars'].apply(label_df)
bon_category_coffee=category_coffee[category_coffee['labels']==1]
bon_category_coffee.to_csv('./output/bon_category_coffee.csv')
mauvais_category_coffee=category_coffee[category_coffee['labels']==0]
mauvais_category_coffee.to_csv('./output/mauvais_category_coffee.csv')
# Out:
# C:\Users\18791\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %% [markdown]
# # mexican

# %%
category_mexican=business_categories_df[business_categories_df['category1']=='mexican']
mean=np.mean(category_mexican.stars)
category_mexican['labels']=category_mexican['stars'].apply(label_df)
bon_category_mexican=category_mexican[category_mexican['labels']==1]
bon_category_mexican.to_csv('./output/bon_category_mexican.csv')
mauvais_category_mexican=category_mexican[category_mexican['labels']==0]
mauvais_category_mexican.to_csv('./output/mauvais_category_mexican.csv')
# Out:
# C:\Users\18791\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %% [markdown]
# # bar

# %%
category_bars=business_categories_df[business_categories_df['category1']=='bars']
mean=np.mean(category_bars.stars)
category_bars['labels']=category_bars['stars'].apply(label_df)
bon_category_bars=category_bars[category_bars['labels']==1]
bon_category_bars.to_csv('./output/bon_category_bars.csv')
mauvais_category_bars=category_bars[category_bars['labels']==0]
mauvais_category_bars.to_csv('./output/mauvais_category_bars.csv')
# Out:
# C:\Users\18791\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
