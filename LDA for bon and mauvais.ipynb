# %%
import pickle
import pandas as pd 
import numpy as np 
# Shared folder to read data
SHARED_FOLDER = './yelp'

# Your folder to write new data and create notebooks.
MY_FOLDER = './output'

# %%
with open ('{}/tip.pickle'.format(SHARED_FOLDER), 'rb') as f:
    tip_df = pickle.load(f)
example_tip_df=tip_df
df =example_tip_df[['business_id','text']].dropna()

# %%
import re
def clean_email_text(text):
    text = text.replace('\n'," ") #new line
    text = re.sub(r"-", " ", text) #separate two words with"-" (july-edu ==> july edu）
    text = re.sub(r"[0-9]+", "", text) #number
    pure_text = ''
    # filter all number and signs
    for letter in text:
        # just letter and blank
        if letter.isalpha() or letter==' ':
            pure_text += letter
    # filter all single words
    text = ' '.join(word for word in pure_text.split() if len(word)>1)
    return text

# %%
with open('stopwords.txt', 'r') as f:  
    stopWords=[l.strip('\n') for l in f.readlines()]
print(stopWords)
# Out:
# ['a', "a's", 'al', 'able', 'about', 'above', 'according', 'accordingly', 'across', 'actually', 'after', 'afterwards', 'again', 'against', "ain't", 'all', 'allow', 'allows', 'almost', 'alone', 'along', 'already', 'also', 'although', 'always', 'am', 'among', 'amongst', 'an', 'and', 'another', 'any', 'anybody', 'anyhow', 'anyone', 'anything', 'anyway', 'anyways', 'anywhere', 'apart', 'appear', 'appreciate', 'appropriate', 'are', "aren't", 'around', 'as', 'aside', 'ask', 'asking', 'associated', 'at', 'available', 'away', 'awfully', 'b', 'be', 'became', 'because', 'become', 'becomes', 'becoming', 'been', 'before', 'beforehand', 'behind', 'being', 'believe', 'below', 'beside', 'besides', 'best', 'better', 'between', 'beyond', 'both', 'brief', 'but', 'by', 'c', "c'mon", "c's", 'came', 'can', "can't", 'cannot', 'cant', 'cause', 'causes', 'certain', 'certainly', 'changes', 'clearly', 'co', 'com', 'come', 'comes', 'concerning', 'consequently', 'consider', 'considering', 'contain', 'containing', 'contains', 'corresponding', 'could', "couldn't", 'course', 'currently', 'd', 'definitely', 'described', 'despite', 'did', "didn't", 'different', 'do', 'does', "doesn't", 'doing', "don't", 'done', 'down', 'downwards', 'during', 'e', 'each', 'edu', 'eg', 'eight', 'either', 'else', 'elsewhere', 'enough', 'entirely', 'especially', 'et', 'etc', 'even', 'ever', 'every', 'everybody', 'everyone', 'everything', 'everywhere', 'ex', 'exactly', 'example', 'except', 'f', 'far', 'few', 'fifth', 'first', 'five', 'followed', 'following', 'follows', 'for', 'former', 'formerly', 'forth', 'four', 'from', 'further', 'furthermore', 'g', 'get', 'gets', 'getting', 'given', 'gives', 'go', 'goes', 'going', 'gone', 'got', 'gotten', 'greetings', 'h', 'had', "hadn't", 'happens', 'hardly', 'has', "hasn't", 'have', "haven't", 'having', 'he', "he's", 'hello', 'help', 'hence', 'her', 'here', "here's", 'hereafter', 'hereby', 'herein', 'hereupon', 'hers', 'herself', 'hi', 'him', 'himself', 'his', 'hither', 'hopefully', 'how', 'howbeit', 'however', 'i', "i'd", "i'll", "i'm", "i've", 'ie', 'if', 'ignored', 'immediate', 'in', 'inasmuch', 'inc', 'indeed', 'indicate', 'indicated', 'indicates', 'inner', 'insofar', 'instead', 'into', 'inward', 'is', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', 'j', 'just', 'k', 'keep', 'keeps', 'kept', 'know', 'knows', 'known', 'l', 'last', 'lately', 'later', 'latter', 'latterly', 'least', 'less', 'lest', 'let', "let's", 'like', 'liked', 'likely', 'little', 'look', 'looking', 'looks', 'ltd', 'm', 'mainly', 'many', 'may', 'maybe', 'me', 'mean', 'meanwhile', 'merely', 'might', 'more', 'moreover', 'most', 'mostly', 'much', 'must', 'my', 'myself', 'n', 'name', 'namely', 'nd', 'near', 'nearly', 'necessary', 'need', 'needs', 'neither', 'never', 'nevertheless', 'new', 'next', 'nine', 'no', 'nobody', 'non', 'none', 'noone', 'nor', 'normally', 'not', 'nothing', 'novel', 'now', 'nowhere', 'o', 'obviously', 'of', 'off', 'often', 'oh', 'ok', 'okay', 'old', 'on', 'once', 'one', 'ones', 'only', 'onto', 'or', 'other', 'others', 'otherwise', 'ought', 'our', 'ours', 'ourselves', 'out', 'outside', 'over', 'overall', 'own', 'p', 'particular', 'particularly', 'per', 'perhaps', 'placed', 'please', 'plus', 'possible', 'presumably', 'probably', 'provides', 'q', 'que', 'quite', 'qv', 'r', 'rather', 'rd', 're', 'really', 'reasonably', 'regarding', 'regardless', 'regards', 'relatively', 'respectively', 'right', 's', 'said', 'same', 'saw', 'say', 'saying', 'says', 'second', 'secondly', 'see', 'seeing', 'seem', 'seemed', 'seeming', 'seems', 'seen', 'self', 'selves', 'sensible', 'sent', 'serious', 'seriously', 'seven', 'several', 'shall', 'she', 'should', "shouldn't", 'since', 'six', 'so', 'some', 'somebody', 'somehow', 'someone', 'something', 'sometime', 'sometimes', 'somewhat', 'somewhere', 'soon', 'sorry', 'specified', 'specify', 'specifying', 'still', 'sub', 'such', 'sup', 'sure', 't', "t's", 'take', 'taken', 'tell', 'tends', 'th', 'than', 'thank', 'thanks', 'thanx ...

# %%
df.text = df.text.apply(lambda s: clean_email_text(s))

# %%
def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print("Topic #%d:" % topic_idx)
        print(" ".join([feature_names[i]
                        for i in topic.argsort()[:-n_top_words - 1:-1]]))
    print()

# %% [markdown]
# # bon restaurant

# %%
bon_df=pd.read_csv('{}/bon_restaurant.csv'.format(SHARED_FOLDER))
bon_df
# Out:
#      Unnamed: 0  Unnamed: 0.1  \
# 0             1             1
# 1             3             3
# 2             5             5
# 3             6             6
# 4             7             7
# 5            11            11
# 6            12            12
# 7            15            15
# 8            16            16
# 9            17            17
# 10           19            19
# 11           22            22
# 12           23            23
# 13           24            24
# 14           25            25
# 15           27            27
# 16           28            28
# 17           29            29
# 18           30            30
# 19           31            31
# 20           32            32
# 21           33            33
# 22           34            34
# 23           35            35
# 24           37            37
# 25           40            40
# 26           42            42
# 27           46            46
# 28           47            47
# 29           48            48
# ..          ...           ...
# 784        1204          1204
# 785        1205          1205
# 786        1206          1206
# 787        1207          1207
# 788        1211          1211
# 789        1212          1212
# 790        1213          1213
# 791        1215          1215
# 792        1217          1217
# 793        1221          1221
# 794        1222          1222
# 795        1223          1223
# 796        1225          1225
# 797        1226          1226
# 798        1228          1228
# 799        1229          1229
# 800        1230          1230
# 801        1231          1231
# 802        1232          1232
# 803        1236          1236
# 804        1237          1237
# 805        1239          1239
# 806        1243          1243
# 807        1246          1246
# 808        1247          1247
# 809        1249          1249
# 810        1250          1250
# 811        1251          1251
# 812        1252          1252
# 813        1254          1254
#
#                                             attributes  \
# 0    {'Dogs Allowed': True, 'Ambience': {'intimate'...
# 1    {'Alcohol': 'none', 'Outdoor Seating': True, '...
# 2    {'Parking': {'lot': True, 'garage': False, 'va...
# 3    {'Noise Level': 'average', 'Wheelchair Accessi...
# 4    {'Wheelchair Accessible': True, 'Attire': 'cas...
# 5    {'Noise Level': 'average', 'Wheelchair Accessi...
# 6    {'Dogs Allowed': True, 'Alcohol': 'full_bar', ...
# 7    {'Alcohol': 'none', 'Outdoor Seating': False, ...
# 8    {'Dogs Allowed': False, 'Ambience': {'intimate...
# 9    {'Good for Kids': True, 'Good For': {'breakfas...
# 10   {'Alcohol': 'none', 'Outdoor Seating': False, ...
# 11   {'Noise Level': 'average', 'Wheelchair Accessi...
# 12   {'Alcohol': 'beer_and_wine', 'Outdoor Seating'...
# 13   {'Alcohol': 'none', 'Has TV': False, 'Attire':...
# 14   {'Good for Kids': False, 'Delivery': False, 'A...
# 15   {'Parking': {'lot': True, 'garage': False, 'va...
# 16   {'Alcohol': 'none', 'Outdoor Seating': False, ...
# 17   {'Noise Level': 'average', 'Wheelchair Accessi...
# 18   {'Noise Level': 'quiet', 'Wheelchair Accessibl...
# 19   {'Alcohol': 'none', 'Outdoor Seating': False, ...
# 20   {'Alcohol': 'none', 'Outdoor Seating': True, '...
# 21   {'Alcohol': 'none', 'Outdoor Seating': False, ...
# 22   {'Dogs Allowed': True, 'Good for Kids': False,...
# 23   {'Parking': {'lot': False, 'garage': False, 'v...
# 24   {'Parking': {'lot': True, 'garage': False, 'va...
# 25   {'Parking': {'lot': True, 'garage': False, 'va...
# 26   {'Noise Level': 'average', 'Wheelchair Accessi...
# 27   {'Alcohol': 'none', 'Outdoor Seating': True, '...
# 28   {'Dogs Allowed': False, 'Ambience': {'intimate...
# 29   {'Dogs Allowed': True, 'Good for Kids': False,...
# ..                                                 ...
# 784  {'Noise Level': 'average', 'Wheelchair Accessi...
# 785  {'Noise Level': 'loud', 'Wheelchair Accessible...
# 786  {'Dogs Allowed': True, 'Ambience': {'intimate'...
# 787  {'Dogs Allowed': True, 'Ambience': {'intimate'...
# 788  {'Wheelchair Accessible': True, 'Outdoor Seati...
# 789  {'Wheelchair Accessible': True, 'Price Range':...
# 790  {'Noise Level': 'quiet', 'Wheelchair Accessibl...
# 791  {'Parking': {'lot': False, 'garage': False, 'v...
# 792  {'Alcohol': 'none', 'Outdoor Seating': False, ...
# 793  {'Alcohol': 'full_bar', 'Outdoor Seating': Fal...
# 794  {'Parking': {'lot': True, 'garage': True, 'val...
# 795  {'Alcohol': 'none', 'Outdoor Seating': True, '...
# 796  {'Wheelchair Accessible': True, 'Price Range':...
# 797  {'Noise Level': 'average', 'Wheelchair Accessi...
# 798  {'BYOB/Corkage': 'yes_free', 'Good for Kids': ...
# 799  {'BYOB/Corkage': 'yes_free', 'Good for Kids': ...
# 800  {'Noise Level': 'average', 'Wheelchair Accessi...
# 801  {'Parking': {'lot': True, 'garage': False, 'va...
# 802  {'Parking': {'lot': True, 'garage': False, 'va...
# 803  {'Parking': {'lot': True, 'garage': False, 'va...
# 804  {'Good For Groups': True, 'Noise Level': 'loud...
# 805  {'Noise Level': 'average', 'Wheelchair Accessi...
# 806  {'Alcohol': 'beer_and_wine', 'Has TV': True, '...
# 807  {'Good for Kids': True, 'Delivery': True, 'Att...
# 808  {'BYOB/Corkage': 'yes_corkage', 'Good for Kids...
# 809  {'Noise Level': 'average', 'Wheelchair Accessi...
# 810  {'Parking': {'lot': False, 'garage': False, 'v...
# 811  {'Noise Level': 'quiet', 'Wheelchair Accessibl...
# 812  {'Dogs Allowed': True, 'Ambience': {'intimate'...
# 813  {'Noise Level': 'average', 'Wheelchair Accessi...
#
#                 business_id  \
# 0    QQ0VZ1ggQO1aVf_GK6kn5g
# 1    QBoynogVWpl44LglOEIYhw
# 2    LTk9XA-htXS-ngVfnnQPUA
# 3    D0tHnskAgaRjCBdoXVev_g
# 4    Kqn4J9NTgZdMAnV4HuYh5A
# 5    cT_rocMh92B9t62Disp6gA
# 6    noaKqyRwXTW4__8p4h5ZSw
# 7    rAb_wfdKKPPbcIysjYcW4A
# 8    hiXt1iC9nJh3--kz80zRtA
# 9    udVKZfBZ3IyZf_mlTy0law
# 10   vGI3QO3wDBuQ2fPXVJmL9A
# 11   TucqtiPHUT9xFT3teOPq-w
# 12   93fEJZYc3B-jOMaXce7G5A
# 13   JeivzPg5TV_o5ZgLBw-hXw
# 14   CIgXglXMtnjjbgG6i0BKJg
# 15   dr3FmOSZ_Iy2WyPnS5ABOA
# 16   9NoaYpTbEG2qn34kq7W3ww
# 17   rsI6iakvvpOTF3pTXAMYBA
# 18   mM4JGpza3KkegHYUN7T79w
# 19   ATeF8pmKd50Xx6Nkd_BsXw
# 20   859jud754SQWHDpIXeBAiQ
# 21   jgWAgT7LWPTf5wju9Q-kiw
# 22   uyQ0mDz0OKEgUkBKWIl3og
# 23   N2vAvUdh_A-Ggs8_csggyA
# 24   EHGuZw0qptzw2M1LF-3sXA
# 25   kOK86MUuK-VWfJEYuvHUnQ
# 26   iNvY0zAlaD_ye7Z6rHu-Ug
# 27   7Y1lfzFkwBRoMZKIMMeZMw
# 28   VQmgq4Dwwej5AwnHBmDIAg
# 29   uwIq5b4uOArJQ1G1AfimiQ
# ..                      ...
# 784  UVEnZjATEGkKLFdzV_dTvA
# 785  32dee8YUFOSBDeIRmG-tPA
# 786  5_tsOGJQDDl9iKOr8K79Rw
# 787  UB2j_EV3CIM_E4LcpadKMQ
# 788  _lDDgqKSwzYKNiCqdGQLHw
# 789  edDmYTcsClAL9XPR8YkvnQ
# 790  tyETqrYijm3cY4noCwl9Ww
# 791  hdAQKv8TZJy8FUwS8QByzQ
# 792  _k2-7p9iwZOvtz59119WvA
# 793  eow0zY6TdViDnyJXXeOMwg
# 794  Fu0bqlXL2R46XlcNkR6KjA
# 795  g6SHDb-0BYr2weF7heRsjg
# 796  -iGegnCdHR1IWw4D_240_Q
# 797  5ErKAS0rHOfU33CYjDh2Aw
# 798  VhraACjnyT90dKMCtxdl1A
# 799  d_8bMNQd0mesbEUeq1U2kQ
# 800  RtwOc-n_RkiUuDGaNfCsNw
# 801  ezh7DWNch2eNHTUyAnV7lg
# 802  ePdWC_PsCuPVboQIje38Rg
# 803  GFWo7WJKmhp_VH6C0gnTDw
# 804  142B55RUI8L5rfwIuVatMA
# 805  Eq3gzgiRIGYtubbZw1mDlQ
# 806  mXIgCWuu6Thb2mXluEYYig
# 807  l57YL2SREyKQyKLqAQ3ZVg
# 808  k6Si433-EJrY4J7SZxsnjA
# 809  Yvk6VWr6SVg6PG4jIep6rQ
# 810  7ZkMXHdSTpzNBOc-LO9H5A
# 811  qc-YDANWNNI3iEwam7wy1w
# 812  jUCgAb0gmvjtOA25I1bQ8A
# 813  g1nyGrCI6ibXlIRLMWtvhA
#
#                                             categories            city  \
# 0    ['Vegetarian', 'Diners', 'Vegan', 'Restaurants...         Phoenix
# 1                        ['Tex-Mex', 'Restaurants', 1]           Tempe
# 2    ['Food', 'Automotive', 'Convenience Stores', '...         Phoenix
# 3                      ['Fast Food', 'Restaurants', 1]           Tempe
# 4                          ['Food', 'Coffee & Tea', 1]         Phoenix
# 5                           ['Thai', 'Restaurants', 1]        Chandler
# 6    ['Burgers', 'Delis', 'American (New)', 'Restau...      Scottsdale
# 7                        ['Mexican', 'Restaurants', 1]         Phoenix
# 8         ['Sushi Bars', 'Japanese', 'Restaurants', 1]        Chandler
# 9                     ['Sandwiches', 'Restaurants', 1]      Wickenburg
# 10                       ['Mexican', 'Restaurants', 1]            Mesa
# 11                            ['Food', 'Empanadas', 1]            Mesa
# 12     ['Italian', 'Pizza', 'Salad', 'Restaurants', 1]         Phoenix
# 13                               ['Food', 'Gelato', 1]      Scottsdale
# 14                     ['Fast Food', 'Restaurants', 1]        Surprise
# 15                              ['Food', 'Grocery', 1]         Phoenix
# 16   ['American (Traditional)', 'Cafes', 'Restauran...      Scottsdale
# 17   ['Italian', 'Pizza', 'Sandwiches', 'Restaurant...            Mesa
# 18         ['Fast Food', 'Japanese', 'Restaurants', 1]         Phoenix
# 19   ['Fast Food', 'Mexican', 'Tex-Mex', 'Restauran...         Phoenix
# 20   ['Food', 'Ice Cream & Frozen Yogurt', 'Fast Fo...            Mesa
# 21                       ['Chinese', 'Restaurants', 1]        Chandler
# 22   ['Nightlife', 'Wine Bars', 'Thai', 'Bars', 'Re...          Peoria
# 23                              ['Food', 'Grocery', 1]        Glendale
# 24    ['Food', 'Food Delivery Services', 'Grocery', 1]         Phoenix
# 25                              ['Food', 'Grocery', 1]        Chandler
# 26           ['Burgers', 'Hot Dogs', 'Restaurants', 1]         Phoenix
# 27          ['Fast Food', 'Mexican', 'Restaurants', 1]          Peoria
# 28   ['American (Traditional)', 'Mexican', 'Chinese...         Phoenix
# 29   ['Gastropubs', 'Bars', 'Restaurants', 'Sports ...      Scottsdale
# ..                                                 ...             ...
# 784                      ['Restaurants', 'Italian', 1]      Scottsdale
# 785           ['Mexican', 'Tex-Mex', 'Restaurants', 1]       El Mirage
# 786                      ['Burgers', 'Restaurants', 1]          Peoria
# 787       ['American (Traditional)', 'Restaurants', 1]      Scottsdale
# 788                        ['Food', 'Coffee & Tea', 1]         Phoenix
# 789  ['Food', 'Juice Bars & Smoothies', 'Shaved Ice...           Tempe
# 790               ['Middle Eastern', 'Restaurants', 1]           Tempe
# 791           ['Food', 'Ice Cream & Frozen Yogurt', 1]          Peoria
# 792       ['American (Traditional)', 'Restaurants', 1]       Youngtown
# 793             ['Italian', 'Pizza', 'Restaurants', 1]         Phoenix
# 794    ['Food', 'Desserts', 'Cupcakes', 'Bakeries', 1]         Gilbert
# 795  ['Breakfast & Brunch', 'Vegetarian', 'Vegan', ...            Mesa
# 796           ['Food', 'Ice Cream & Frozen Yogurt', 1]        Surprise
# 797             ['Italian', 'Pizza', 'Restaurants', 1]         Phoenix
# 798  ['Nightlife', 'Irish', 'Bars', 'Sports Bars', ...      Scottsdale
# 799  ['Pakistani', 'Indian', 'Buffets', 'Restaurant...         Phoenix
# 800  ['Food', 'Desserts', 'Cheesesteaks', 'Sandwich...           Tempe
# 801  ['Food', 'Specialty Food', 'Grocery', 'Fruits ...         Gilbert
# 802                             ['Food', 'Grocery', 1]           Tempe
# 803  ['Food', 'Automotive', 'Convenience Stores', '...            Mesa
# 804                        ['Pizza', 'Restaurants', 1]      Scottsdale
# 805  ['Caterers', 'Mexican', 'Event Planning & Serv...        Chandler
# 806                      ['Chinese', 'Restaurants', 1]         Phoenix
# 807           ['Fast Food', 'Pizza', 'Restaurants', 1]        Chandler
# 808  ['Bars', 'Wine Bars', 'Nightlife', 'Italian', ...      Scottsdale
# 809  ['Korean', 'Sushi Bars', 'Japanese', 'Restaura...        Chandler
# 810  ['Shopping', 'Drugstores', 'Beauty & Spas', 'F...        Glendale
# 811                      ['Chinese', 'Restaurants', 1]            Mesa
# 812  ['Gastropubs', 'American (New)', 'Restaurants'...      Scottsdale
# 813  ['Food', 'Ethnic Food', 'Specialty Food', 'Med...  Fountain Hills
#
#                                                  hours   latitude   longitude  \
# 0    {'Monday': {'close': '16:00', 'open': '07:00'}...  33.457226 -112.089834
# 1                                                   {}  33.414355 -111.926294
# 2    {'Monday': {'close': '00:00', 'open': '00:00'}...  33.479867 -112.117920
# 3                                                   {}  33.407353 -111.945569
# 4                                                   {}  33.675854 -111.966734
# 5    {'Monday': {'close': '21:00', 'open': '11:00'}...  33.306465 -111.877826
# 6    {'Monday': {'close': '21:00', 'open': '11:00'}...  33.671877 -111.905845
# 7                                                   {}  33.450927 -112.021199
# 8    {'Monday': {'close': '21:30', 'open': '16:30'}...  33.304296 -111.840548
# 9    {'Monday': {'close': '16:00', 'open': '07:30'}...  33.969238 -112.730715
# 10                                                  {}  33.422290 -111.737502
# 11   {'Monday': {'close': '21:00', 'open': '11:00'}...  33.413460 -111.825846
# 12   {'Monday': {'close': '21:00', 'open': '10:30'}...  33.666693 -112.124353
# 13   {'Tuesday': {'close': '20:00', 'open': '12:00'...  33.492253 -111.922980
# 14                                                  {}  33.639122 -112.354812
# 15   {'Monday': {'close': '23:00', 'open': '06:00'}...  33.627232 -112.012115
# 16   {'Monday': {'close': '14:00', 'open': '08:00'}...  33.568525 -111.886316
# 17   {'Monday': {'close': '21:00', 'open': '10:30'}...  33.362575 -111.635310
# 18   {'Monday': {'close': '19:00', 'open': '10:30'}...  33.512745 -112.100296
# 19   {'Monday': {'close': '00:00', 'open': '07:00'}...  33.611060 -112.111991
# 20                                                  {}  33.414874 -111.817630
# 21   {'Monday': {'close': '21:00', 'open': '11:00'}...  33.319531 -111.859262
# 22   {'Tuesday': {'close': '21:00', 'open': '11:00'...  33.635355 -112.235027
# 23                                                  {}  33.669149 -112.202451
# 24                                                  {}  33.450000 -112.070000
# 25   {'Monday': {'close': '23:00', 'open': '06:00'}...  33.307328 -111.874897
# 26   {'Monday': {'close': '20:00', 'open': '10:30'}...  33.494774 -112.000043
# 27   {'Monday': {'close': '22:00', 'open': '10:00'}...  33.711978 -112.274706
# 28   {'Monday': {'close': '18:00', 'open': '06:00'}...  33.451615 -112.085725
# 29   {'Monday': {'close': '02:00', 'open': '11:00'}...  33.501263 -111.922367
# ..                                                 ...        ...         ...
# 784  {'Monday': {'close': '21:00', 'open': '17:00'}...  33.587356 -111.837278
# 785  {'Monday': {'close': '21:00', 'open': '11:00'}...  33.617436 -112.324297
# 786  {'Monday': {'close': '20:00', 'open': '11:00'}...  33.553539 -112.270790
# 787  {'Monday': {'close': '22:00', 'open': '16:00'}...  33.597840 -111.978111
# 788  {'Monday': {'close': '21:00', 'open': '04:30'}...  33.710978 -112.111411
# 789  {'Monday': {'close': '22:00', 'open': '12:00'}...  33.335384 -111.927076
# 790  {'Monday': {'close': '21:00', 'open': '11:00'}...  33.393622 -111.908116
# 791                                                 {}  33.712725 -112.278124
# 792  {'Thursday': {'close': '14:00', 'open': '06:00...  33.603614 -112.302096
# 793  {'Monday': {'close': '00:00', 'open': '17:00'}...  33.458478 -112.078155
# 794  {'Monday': {'close': '21:00', 'open': '10:30'}...  33.377949 -111.740968
# 795  {'Thursday': {'close': '14:30', 'open': '07:30...  33.362933 -111.875324
# 796                                                 {}  33.638145 -112.365227
# 797  {'Monday': {'close': '22:30', 'open': '10:30'}...  33.610825 -112.131028
# 798  {'Monday': {'close': '02:00', 'open': '11:00'}...  33.641669 -111.862020
# 799  {'Tuesday': {'close': '21:30', 'open': '17:00'...  33.304667 -111.994582
# 800  {'Monday': {'close': '20:00', 'open': '11:00'}...  33.335639 -111.962558
# 801  {'Monday': {'close': '22:00', 'open': '07:00'}...  33.303695 -111.757137
# 802                                                 {}  33.394024 -111.939619
# 803  {'Monday': {'close': '00:00', 'open': '00:00'}...  33.414894 -111.754369
# 804                                                 {}  33.647108 -111.892844
# 805                                                 {}  33.301390 -111.841299
# 806                                                 {}  33.451616 -112.090549
# 807  {'Monday': {'close': '23:00', 'open': '10:30'}...  33.305552 -111.874421
# 808  {'Monday': {'close': '22:00', 'open': '11:00'}...  33.493266 -111.931033
# 809  {'Monday': {'close': '21:00', 'open': '16:00'}...  33.319241 -111.925850
# 810  {'Monday': {'close': '22:00', 'open': '08:00'}...  33.537036 -112.238354
# 811  {'Monday': {'close': '21:00', 'open': '11:00'}...  33.379586 -111.849963
# 812                                                 {}  33.625641 -111.932547
# 813  {'Monday': {'close': '20:00', 'open': '11:00'}...  33.573931 -111.714056
#
#       open   ...    hours.Thursday.open  hours.Tuesday.close  \
# 0    False   ...                      7                   16
# 1     True   ...                     25                   25
# 2     True   ...                      0                    0
# 3     True   ...                     25                   25
# 4    False   ...                     25                   25
# 5     True   ...                     11                   21
# 6    False   ...                     11                   21
# 7     True   ...                     25                   25
# 8     True   ...                     16                   21
# 9     True   ...                      7                   16
# 10    True   ...                     25                   25
# 11    True   ...                     11                   21
# 12    True   ...                     10                   21
# 13    True   ...                     12                   20
# 14    True   ...                     25                   25
# 15    True   ...                      6                   23
# 16    True   ...                      8                   14
# 17    True   ...                     10                   21
# 18    True   ...                     10                   19
# 19    True   ...                      7                    0
# 20    True   ...                     25                   25
# 21    True   ...                     11                   21
# 22   False   ...                     11                   21
# 23    True   ...                     25                   25
# 24    True   ...                     25                   25
# 25    True   ...                      6                   23
# 26    True   ...                     10                   20
# 27    True   ...                     10                   22
# 28    True   ...                      6                   18
# 29    True   ...                     11                    2
# ..     ...   ...                    ...                  ...
# 784   True   ...                     17                   21
# 785   True   ...                     11                   21
# 786   True   ...                     11                   20
# 787   True   ...                     16                   22
# 788   True   ...                      4                   21
# 789   True   ...                     12                   22
# 790  False   ...                     11                   21
# 791   True   ...                     25                   25
# 792   True   ...                      6                   14
# 793   True   ...                     17                    0
# 794   True   ...                     10                   21
# 795   True   ...                      7                   14
# 796  False   ...                     25                   25
# 797   True   ...                     10                   22
# 798   True   ...                     11                    2
# 799   True   ...                     17                   21
# 800   True   ...                     11                   20
# 801   True   ...                      7                   22
# 802   True   ...                     25                   25
# 803   True   ...                      0                    0
# 804  False   ...                     25                   25
# 805   True   ...                     25                   25
# 806  False   ...                     25                   25
# 807   True   ...                     10                   23
# 808   True   ...                     11                   22
# 809  False   ...                     16                   21
# 810   True   ...                      7                   22
# 811   True   ...                     11                   21
# 812   True   ...                     25                   25
# 813   True   ...                     11                   20
#
#      hours.Tuesday.open  hours.Wednesday.close  hours.Wednesday.open  \
# 0                     7                     16                     7
# 1                    25                     25                    25
# 2                     0                      0                     0
# 3                    25                     25                    25
# 4                    25                     25                    25
# 5                    11                     21                    11
# 6                    11                     21                    11
# 7                    25                     25                    25
# 8                    16                     21                    16
# 9                     7                     16                     7
# 10                   25                     25                    25
# 11                   11                     21                    11
# 12                   10                     21                    10
# 13                   12                     20                    12
# 14                   25                     25                    25
# 15                    6                     23                     6
# 16                    8                     14                     8
# 17                   10                     21                    10
# 18                   10                     19                    10
# 19                    7                      0                     7
# 20                   25                     25                    25
# 21                   11                     25                    25
# 22                   11                     21                    11
# 23                   25                     25                    25
# 24                   25                     25                    25
# 25                    6                     23                     6
# 26                   10                     20                    10
# 27                   10                     22                    10
# 28                    6                     18                     6
# 29                   11                      2                    11
# ..                  ...                    ...                   ...
# 784                  17                     21                    17
# 785                  11                     21                    11
# 786                  11                     20                    11
# 787                  16                     22                    16
# 788                   4                     21                     4
# 789                  12                     22                    12
# 790                  11                     21                    11
# 791                  25                     25                    25
# 792                   6                     14                     6
# 793                  17                      0                    17
# 794                  10                     21                    10
# 795                   7                     14                     7
# 796                  25                     25                    25
# 797                  10                     22                    10
# 798                  11                      2                    11
# 799                  17                     21                    17
# 800                  11                     20                    11
# 801                   7                     22                     7
# 802                  25                     25                    25
# 803                   0                      0                     0
# 804                  25                     25                    25
# 805                  25                     25                    25
# 806                  25                     25                    25
# 807                  10                     23                    10
# 808                  11                     22                    11
# 809                  16                     21                    16
# 810                   7                     22                     7
# 811                  11                     21                    11
# 812                  25                     25                    25
# 813                  11                     20                    11
#
#      avg_review_stars  reviews_count  tip_count  checkin_count  labels
# 0            4.216080            199         45            620       2
# 1            3.500000             46          9            150       2
# 2            4.200000              5          2            124       2
# 3            3.666667             27         15            178       2
# 4            4.338710             62         15            171       2
# 5            3.748792            207         44            527       2
# 6            3.857143             21         11             29       2
# 7            3.916667             12          2             22       2
# 8            3.553846             65         17            229       2
# 9            4.268293             41         12            104       2
# 10           4.000000              5          6             22       2
# 11           4.425373            268         45            514       2
# 12           4.206250            160         46            527       2
# 13           4.655172             58         18            154       2
# 14           2.666667              3          4             17       2
# 15           3.900000             10          8             71       2
# 16           4.200000             20          7             50       2
# 17           4.042553             47         12             44       2
# 18           3.451613             31         23            137       2
# 19           3.000000              9          2             37       2
# 20           3.500000              4          2             21       2
# 21           4.043269            208         45            535       2
# 22           3.388889            108         25            208       2
# 23           3.666667              3          4             31       2
# 24           4.108108             74          3             18       2
# 25           3.647059             17          4            241       2
# 26           4.083700            227         64            668       2
# 27           3.388889             18          4             43       2
# 28           4.475410             61         15             88       2
# 29           3.837838             37          4            920       2
# ..                ...            ...        ...            ...     ...
# 784          4.319588             97         14             57       2
# 785          4.000000             95         24            226       2
# 786          3.906077            181         39            546       2
# 787          4.154217            415         84           1152       2
# 788          3.833333             30         30            541       2
# 789          4.087500             80         27            506       2
# 790          4.222930            157         34            334       2
# 791          5.000000              4          3             40       2
# 792          4.633333             30          1             18       2
# 793          4.546667             75         11            102       2
# 794          4.217949             78         18            125       2
# 795          4.885246             61          5            118       2
# 796          3.800000             10         13            112       2
# 797          4.148649             74         13            317       2
# 798          3.588235            102         32            500       2
# 799          4.046729            107         33            249       2
# 800          4.240157            254         67            735       2
# 801          4.237288             59         22           1149       2
# 802          3.400000              5          1             37       2
# 803          4.750000              4         10            149       2
# 804          3.625000              8          7             46       2
# 805          3.525000             80         16            246       2
# 806          3.222222              9          2             13       2
# 807          3.666667              3          2              6       2
# 808          3.534979            243         44            508       2
# 809          3.763359            131         33            242       2
# 810          4.666667              3          1             33       2
# 811          4.320000             50         25            134       2
# 812          3.923077             13          3             67       2
# 813          4.711864             59         20            112       2
#
# [814 rows x 120 columns]

# %%
bon_df=bon_df[['business_id']].merge(df, on='business_id', how='inner',
                                         suffixes=['business','review'])
bon_df
# Out:
#                  business_id  \
# 0     zmvIqh26-lzpZROHuhA-6w
# 1     zmvIqh26-lzpZROHuhA-6w
# 2     zmvIqh26-lzpZROHuhA-6w
# 3     zmvIqh26-lzpZROHuhA-6w
# 4     zmvIqh26-lzpZROHuhA-6w
# 5     zmvIqh26-lzpZROHuhA-6w
# 6     zmvIqh26-lzpZROHuhA-6w
# 7     zmvIqh26-lzpZROHuhA-6w
# 8     zmvIqh26-lzpZROHuhA-6w
# 9     zmvIqh26-lzpZROHuhA-6w
# 10    zmvIqh26-lzpZROHuhA-6w
# 11    zmvIqh26-lzpZROHuhA-6w
# 12    zmvIqh26-lzpZROHuhA-6w
# 13    zmvIqh26-lzpZROHuhA-6w
# 14    zmvIqh26-lzpZROHuhA-6w
# 15    zmvIqh26-lzpZROHuhA-6w
# 16    zmvIqh26-lzpZROHuhA-6w
# 17    zmvIqh26-lzpZROHuhA-6w
# 18    zmvIqh26-lzpZROHuhA-6w
# 19    zmvIqh26-lzpZROHuhA-6w
# 20    zmvIqh26-lzpZROHuhA-6w
# 21    zmvIqh26-lzpZROHuhA-6w
# 22    zmvIqh26-lzpZROHuhA-6w
# 23    zmvIqh26-lzpZROHuhA-6w
# 24    zmvIqh26-lzpZROHuhA-6w
# 25    zmvIqh26-lzpZROHuhA-6w
# 26    zmvIqh26-lzpZROHuhA-6w
# 27    zmvIqh26-lzpZROHuhA-6w
# 28    zmvIqh26-lzpZROHuhA-6w
# 29    zmvIqh26-lzpZROHuhA-6w
# ...                      ...
# 5532  5_tsOGJQDDl9iKOr8K79Rw
# 5533  5_tsOGJQDDl9iKOr8K79Rw
# 5534  5_tsOGJQDDl9iKOr8K79Rw
# 5535  5_tsOGJQDDl9iKOr8K79Rw
# 5536  5_tsOGJQDDl9iKOr8K79Rw
# 5537  5_tsOGJQDDl9iKOr8K79Rw
# 5538  5_tsOGJQDDl9iKOr8K79Rw
# 5539  5_tsOGJQDDl9iKOr8K79Rw
# 5540  5_tsOGJQDDl9iKOr8K79Rw
# 5541  5_tsOGJQDDl9iKOr8K79Rw
# 5542  5_tsOGJQDDl9iKOr8K79Rw
# 5543  5_tsOGJQDDl9iKOr8K79Rw
# 5544  5_tsOGJQDDl9iKOr8K79Rw
# 5545  5_tsOGJQDDl9iKOr8K79Rw
# 5546  5_tsOGJQDDl9iKOr8K79Rw
# 5547  5_tsOGJQDDl9iKOr8K79Rw
# 5548  5_tsOGJQDDl9iKOr8K79Rw
# 5549  5_tsOGJQDDl9iKOr8K79Rw
# 5550  5_tsOGJQDDl9iKOr8K79Rw
# 5551  5_tsOGJQDDl9iKOr8K79Rw
# 5552  5_tsOGJQDDl9iKOr8K79Rw
# 5553  5_tsOGJQDDl9iKOr8K79Rw
# 5554  5_tsOGJQDDl9iKOr8K79Rw
# 5555  5_tsOGJQDDl9iKOr8K79Rw
# 5556  5_tsOGJQDDl9iKOr8K79Rw
# 5557  5_tsOGJQDDl9iKOr8K79Rw
# 5558  5_tsOGJQDDl9iKOr8K79Rw
# 5559  5_tsOGJQDDl9iKOr8K79Rw
# 5560  5_tsOGJQDDl9iKOr8K79Rw
# 5561  5_tsOGJQDDl9iKOr8K79Rw
#
#                                                    text
# 0     They reopen at 4:30pm for dinner. Come around ...
# 1                                  Best gyro I've found
# 2                                           Spicy Humus
# 3     Just had carry out and I was impressed with th...
# 4                              Closes for lunch at 2pm.
# 5     I love it all including the big guy behind the...
# 6     Love this place. Best gyro ever, I could eat h...
# 7                            Hummus that hits the spot!
# 8                                            First time
# 9                                               Lunch!!
# 10                  Love the stuffed grape leaves here!
# 11                               Gyros are best in town
# 12    New summer hours beware! Call before planning ...
# 13                            So good. Highly recommend
# 14    Food consistently taste great. Always fresh a ...
# 15    They have been consistently horroble in regard...
# 16    Awesome food. Owner is also very helpful with ...
# 17                                     Closed on Sunday
# 18                                   Great spicy humus!
# 19    Great service & wonderful people that work the...
# 20               Best mediterranean food in the valley!
# 21                                                 Yum.
# 22    The food seems decent here but the service suc...
# 23    Best fries ever, but you have to eat them fres...
# 24    Try the gyro plate. It's enough to satisfy any...
# 25    Love this place great service and fantastic fo...
# 26    Spicy chicken shawarma is the best in east val...
# 27    I love this place, by far the very best hummus...
# 28    Gyros & Shawarma's are always consistent and g...
# 29                                          Great fries
# ...                                                 ...
# 5532           i love this place!!! sonya is awesome!!!
# 5533                                    Great burgers!!
# 5534                Come at lunch as the deals are good
# 5535                      My new favorite burger joint.
# 5536  Don't give your money to this place... The own...
# 5537                             Feels good to be DUKE!
# 5538  Wow take a look at tommys pic and review, boyc...
# 5539  This scum bag is still refusing to pay numerou...
# 5540  First time here. Lots of options with extra fe...
# 5541                      Best service. . Great food!!!
# 5542  Kobe beef (medium), a green chile, bleu cheese...
# 5543  Bison burger with lettuce as bun amazing! ! Co...
# 5544  Dispute against this POS through the labor boa...
# 5545                  Their Blu Burger is ridiculous! ‼
# 5546  Couldn't be a more perfect name for this place...
# 5547    Tonight super busy short a cook= long wait.....
# 5548             Blu chicken on sourdough. Seriously!!!
# 5549  Smells like burgers right inside the door! Goo...
# 5550  Third trip to blue burger. Take it order. Grea...
# 5551                        One word says it all.  Yum!
# 5552  Get the mix basket off the starters and order ...
# 5553                     Best burger in the west valley
# 5554  Read toriana's review and pics, very eye openi...
# 5555         Order the Kobe beef burger. It's amazing!!
# 5556                         The burgers are wonderful!
# 5557                    Needs new paint, looks run down
# 5558  Turkey burger with spinach, pepper jack, jalap...
# 5559  I love the build your own burger. The Kobe bur...
# 5560  They just remodeled and I love the new look. I...
# 5561  Kobe beef, whole wheat, bleu cheese, green chi...
#
# [5562 rows x 2 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
n_features = 1000
tf_vectorizer = CountVectorizer(strip_accents = 'unicode',
                                ngram_range=(2, 3),
                                max_features=n_features,
                                stop_words=stopWords)
tf = tf_vectorizer.fit_transform(bon_df.text)

# %%
from sklearn.decomposition import LatentDirichletAllocation
n_topics = 5
lda = LatentDirichletAllocation(n_topics=n_topics, max_iter=50,
                                learning_method='online',
                                learning_offset=50.,
                                random_state=0)
lda.fit(tf)
# Out:
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#              evaluate_every=-1, learning_decay=0.7,
#              learning_method='online', learning_offset=50.0,
#              max_doc_update_iter=100, max_iter=50, mean_change_tol=0.001,
#              n_jobs=1, n_topics=5, perp_tol=0.1, random_state=0,
#              topic_word_prior=None, total_samples=1000000.0, verbose=0)

# %%
n_top_words = 20
tf_feature_names = tf_vectorizer.get_feature_names()
print_top_words(lda, tf_feature_names, n_top_words)
# Out:
# Topic #0:
# food service taco tuesday good service service food customer service kilt lifter spring rolls pulled pork slow service street tacos food amazing friday night pork sandwich highly recommended excellent service great lunch great spot eat free hey halperin waiting jill
# Topic #1:
# love place pumpkin porter fish tacos carne asada place great awesome food peach ale ice tea mai tai late night great atmosphere great drinks delicious food don miss chips salsa place awesome animal style staff great asada burrito beer bread
# Topic #2:
# mexican food great coffee don forget coming back taco time shrimp tacos breakfast burrito prickly pear ice cream naco torta great breakfast damn good yummy food lunch dinner corn bread tiki time excellent food green chile call ahead service today
# Topic #3:
# happy hour good food food good mac cheese bloody mary great beer great happy hour great happy highly recommend love food friendly service service good oatmeal stout breakfast burritos happy hour day hour day good happy hour good happy iced coffee great bbq
# Topic #4:
# great food great service food great great place honey vanilla vanilla latte honey vanilla latte service great friendly staff pretty good great food great super friendly food awesome food great service hop knot live music worth wait favorite place love love beer great

# %%
import pyLDAvis
import pyLDAvis.sklearn
pyLDAvis.enable_notebook()
pyLDAvis.sklearn.prepare(lda, tf, tf_vectorizer)
# Out:
# PreparedData(topic_coordinates=            Freq  cluster  topics         x         y
# topic
# 3      22.000995        1       1  0.312817 -0.056155
# 0      20.920736        1       2 -0.030170 -0.001199
# 4      20.301307        1       3 -0.168367 -0.257252
# 2      18.681884        1       4 -0.007527  0.078633
# 1      18.095079        1       5 -0.106753  0.235974, topic_info=     Category        Freq                 Term       Total  loglift  logprob
# term
# 507   Default  184.000000           happy hour  184.000000  30.0000  30.0000
# 442   Default  117.000000           great food  117.000000  29.0000  29.0000
# 616   Default   63.000000           love place   63.000000  28.0000  28.0000
# 473   Default   61.000000        great service   61.000000  27.0000  27.0000
# 342   Default   49.000000           food great   49.000000  26.0000  26.0000
# 398   Default   52.000000            good food   52.000000  25.0000  25.0000
# 466   Default   43.000000          great place   43.000000  24.0000  24.0000
# 767   Default   34.000000       pumpkin porter   34.000000  23.0000  23.0000
# 315   Default   28.000000           fish tacos   28.000000  22.0000  22.0000
# 539   Default   29.000000        honey vanilla   29.000000  21.0000  21.0000
# 946   Default   29.000000        vanilla latte   29.000000  20.0000  20.0000
# 161   Default   27.000000          carne asada   27.000000  19.0000  19.0000
# 340   Default   30.000000            food good   30.000000  18.0000  18.0000
# 540   Default   28.000000  honey vanilla latte   28.000000  17.0000  17.0000
# 831   Default   25.000000        service great   25.000000  16.0000  16.0000
# 733   Default   23.000000          place great   23.000000  15.0000  15.0000
# 46    Default   21.000000         awesome food   21.000000  14.0000  14.0000
# 359   Default   31.000000         food service   31.000000  13.0000  13.0000
# 384   Default   21.000000       friendly staff   21.000000  12.0000  12.0000
# 710   Default   19.000000            peach ale   19.000000  11.0000  11.0000
# 562   Default   18.000000              ice tea   18.000000  10.0000  10.0000
# 900   Default   20.000000         taco tuesday   20.000000   9.0000   9.0000
# 644   Default   18.000000         mexican food   18.000000   8.0000   8.0000
# 434   Default   17.000000         great coffee   17.000000   7.0000   7.0000
# 420   Default   18.000000         good service   18.000000   6.0000   6.0000
# 828   Default   18.000000         service food   18.000000   5.0000   5.0000
# 240   Default   17.000000     customer service   17.000000   4.0000   4.0000
# 582   Default   17.000000          kilt lifter   17.000000   3.0000   3.0000
# 635   Default   18.000000           mac cheese   18.000000   2.0000   2.0000
# 121   Default   18.000000          bloody mary   18.000000   1.0000   1.0000
# ...       ...         ...                  ...         ...      ...      ...
# 315    Topic5   27.454805           fish tacos   28.151232   1.6845  -3.6841
# 161    Topic5   26.624894          carne asada   27.320085   1.6838  -3.7148
# 733    Topic5   22.460411          place great   23.164649   1.6787  -3.8849
# 46     Topic5   21.231091         awesome food   21.929127   1.6772  -3.9412
# 710    Topic5   18.613258            peach ale   19.309939   1.6728  -4.0728
# 562    Topic5   18.271713              ice tea   18.976411   1.6717  -4.0913
# 636    Topic5   14.445719              mai tai   15.139402   1.6626  -4.3262
# 590    Topic5   11.197976           late night   11.892839   1.6493  -4.5809
# 438    Topic5   10.692685         great drinks   11.388332   1.6465  -4.6271
# 253    Topic5   10.397645       delicious food   11.097647   1.6444  -4.6550
# 261    Topic5    9.786258             don miss   10.481283   1.6409  -4.7156
# 186    Topic5    9.056646          chips salsa    9.750603   1.6357  -4.7931
# 722    Topic5    9.004408        place awesome    9.706944   1.6344  -4.7989
# 31     Topic5    8.207965         animal style    8.901536   1.6284  -4.8915
# 879    Topic5    8.068576          staff great    8.768340   1.6264  -4.9087
# 37     Topic5    7.790328        asada burrito    8.485149   1.6241  -4.9437
# 889    Topic5    7.362950           super nice    8.065315   1.6184  -5.0002
# 952    Topic5    7.345464            wait back    8.049325   1.6180  -5.0025
# 422    Topic5    7.218276           good stuff    7.913112   1.6176  -5.0200
# 122    Topic5    7.079145         bloody marys    7.772670   1.6161  -5.0395
# 388    Topic5    7.085796         gallo blanco    7.780482   1.6160  -5.0385
# 162    Topic5    7.000677  carne asada burrito    7.695730   1.6149  -5.0506
# 480    Topic5    6.832555          great tacos    7.527062   1.6127  -5.0749
# 585    Topic5    6.793796            kobe beef    7.487858   1.6123  -5.0806
# 311    Topic5    6.656912           fish chips    7.351248   1.6103  -5.1010
# 439    Topic5    6.460125     great experience    7.156387   1.6072  -5.1310
# 603    Topic5    6.152332            long time    6.846544   1.6026  -5.1798
# 233    Topic5    6.000883         cream cheese    6.695091   1.6001  -5.2047
# 427    Topic5   11.156926     great atmosphere   16.884761   1.2952  -4.5846
# 95     Topic5    7.416097           beer bread   10.704397   1.3425  -4.9930
#
# [190 rows x 6 columns], token_table=      Topic      Freq                  Term
# term
# 20        3  0.922596          amazing food
# 31        5  0.898721          animal style
# 37        5  0.942824         asada burrito
# 46        5  0.957630          awesome food
# 51        2  0.938858         awesome place
# 53        2  0.568617       awesome service
# 53        3  0.379078       awesome service
# 58        4  0.874036             baby back
# 87        2  0.932485              bbq town
# 95        3  0.280259            beer bread
# 95        5  0.653937            beer bread
# 98        3  0.961905            beer great
# 121       1  0.977394           bloody mary
# 122       5  0.900591          bloody marys
# 130       4  0.964294     breakfast burrito
# 131       1  0.953810    breakfast burritos
# 136       2  0.884512    breakfast sandwich
# 147       2  0.947708          broncos game
# 158       4  0.856152            call ahead
# 161       5  0.988284           carne asada
# 162       5  0.909595   carne asada burrito
# 186       5  0.923020           chips salsa
# 189       2  0.942448         chopped salad
# 203       3  0.860407           coffee shop
# 221       4  0.928623           coming back
# 224       4  0.906635            corn bread
# 228       4  0.950956        cowboy cowgirl
# 233       5  0.896179          cream cheese
# 240       2  0.946611      customer service
# 243       4  0.916300             damn good
# ...     ...       ...                   ...
# 817       2  0.966678            served day
# 822       2  0.864082           service bad
# 828       2  0.942802          service food
# 829       1  0.916612          service good
# 831       3  0.969309         service great
# 832       3  0.951209    service great food
# 839       4  0.920985          service slow
# 842       4  0.858229         service today
# 858       4  0.945897          shrimp tacos
# 870       2  0.963777          slow service
# 876       2  0.957894          spring rolls
# 879       5  0.912373           staff great
# 883       2  0.788918          street tacos
# 883       4  0.182058          street tacos
# 887       3  0.943600        super friendly
# 888       3  0.860753  super friendly staff
# 889       5  0.867914            super nice
# 890       4  0.951907           surfer roll
# 898       2  0.904806          sweet potato
# 899       4  0.937345             taco time
# 900       2  0.970932          taco tuesday
# 918       4  0.916698             tiki time
# 946       3  0.975174         vanilla latte
# 952       5  0.869638             wait back
# 958       2  0.882084          waiting jill
# 963       1  0.880813       wednesday night
# 981       2  0.973417      won disappointed
# 991       3  0.963511            worth wait
# 995       1  0.918538               yum yum
# 997       4  0.972096            yummy food
#
# [166 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[4, 1, 5, 3, 2])

# %% [markdown]
# # mauvais restaurant

# %%
mauvais_df=pd.read_csv('{}/mauvais_restaurant.csv'.format(SHARED_FOLDER))
mauvais_df=bon_df[['business_id']].merge(df, on='business_id', how='inner',
                                         suffixes=['business','review'])
mauvais_df=mauvais_df.head(80000)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
n_features = 1000
tf_vectorizer = CountVectorizer(strip_accents = 'unicode',
                                ngram_range=(2, 3),
                                max_features=n_features,
                                stop_words=stopWords)
tf = tf_vectorizer.fit_transform(mauvais_df.text)
from sklearn.decomposition import LatentDirichletAllocation
n_topics = 5
lda = LatentDirichletAllocation(n_topics=n_topics, max_iter=50,
                                learning_method='online',
                                learning_offset=50.,
                                random_state=0)
lda.fit(tf)
n_top_words = 20
tf_feature_names = tf_vectorizer.get_feature_names()
print_top_words(lda, tf_feature_names, n_top_words)
# Out:
# Topic #0:
# comfort food amazing food ll back coming back gallo torta el gallo torta el gallo great breakfast excellent breakfast breakfast burrito people good breakfast spot vegetarian options coffee great great coffee great service service great food good wait long excellent breakfast wonderful
# Topic #1:
# love place great place food great great service great atmosphere animal style good stuff late night favorite place pollo fundido cool place service food hash browns great food great food great pond ducks drinks good don bother top shelf pretty good
# Topic #2:
# good food drink menu cauliflower calabrese hip hop snack plate roast beef night downtown moscow mules st germain downtown phoenix eat free kids eat kids eat free beef sandwich roast beef sandwich dirty martinis beet salad pimm cup prosciutto pizza date night
# Topic #3:
# great food pork sandwich slow service grilled pork iced coffee time wait don miss pulled pork sandwich pulled pork grilled pork sandwich time great food relaxed great food relaxed breakfast family call ahead huge portions bbq pork food service torta delicious outdoor seating
# Topic #4:
# food service lunch dinner bring cash banh mi bbq pork long time delicious breakfast croque madame nice patio service wonderful breakfast lunch dinner breakfast lunch place breakfast service good service sucks wait back review place deliciously prepared full service full service wonderful

# %%
import pyLDAvis
import pyLDAvis.sklearn
pyLDAvis.enable_notebook()
pyLDAvis.sklearn.prepare(lda, tf, tf_vectorizer)
# Out:
# PreparedData(topic_coordinates=            Freq  cluster  topics         x         y
# topic
# 0      38.343040        1       1  0.012734  0.249767
# 4      19.682743        1       2 -0.309120  0.168674
# 2      17.428001        1       3  0.305537  0.076424
# 3      15.705190        1       4 -0.163854 -0.320717
# 1       8.841026        1       5  0.154703 -0.174148, topic_info=     Category         Freq                   Term        Total  loglift  \
# term
# 403   Default  2075.000000             great food  2075.000000  30.0000
# 565   Default  1070.000000             love place  1070.000000  29.0000
# 415   Default   956.000000            great place   956.000000  28.0000
# 727   Default  1089.000000          pork sandwich  1089.000000  27.0000
# 377   Default   942.000000              good food   942.000000  26.0000
# 422   Default   770.000000          great service   770.000000  25.0000
# 312   Default   593.000000             food great   593.000000  24.0000
# 391   Default   555.000000       great atmosphere   555.000000  23.0000
# 519   Default   792.000000             late night   792.000000  22.0000
# 329   Default  1083.000000           food service  1083.000000  21.0000
# 25    Default   498.000000           animal style   498.000000  20.0000
# 383   Default   486.000000             good stuff   486.000000  19.0000
# 283   Default   394.000000         favorite place   394.000000  18.0000
# 718   Default   392.000000          pollo fundido   392.000000  17.0000
# 170   Default   365.000000             cool place   365.000000  16.0000
# 877   Default   479.000000           slow service   479.000000  15.0000
# 135   Default   496.000000  cauliflower calabrese   496.000000  14.0000
# 225   Default   496.000000             drink menu   496.000000  13.0000
# 455   Default   496.000000                hip hop   496.000000  12.0000
# 800   Default   496.000000             roast beef   496.000000  11.0000
# 633   Default   496.000000         night downtown   496.000000  10.0000
# 880   Default   496.000000            snack plate   496.000000   9.0000
# 608   Default   496.000000           moscow mules   496.000000   8.0000
# 895   Default   496.000000             st germain   496.000000   7.0000
# 222   Default   496.000000       downtown phoenix   496.000000   6.0000
# 432   Default   461.000000           grilled pork   461.000000   5.0000
# 573   Default   519.000000           lunch dinner   519.000000   4.0000
# 842   Default   332.000000           service food   332.000000   3.0000
# 469   Default   431.000000            iced coffee   431.000000   2.0000
# 445   Default   319.000000            hash browns   319.000000   1.0000
# ...       ...          ...                    ...          ...      ...
# 25     Topic5   498.017331           animal style   498.851212   2.4241
# 383    Topic5   485.735100             good stuff   486.568965   2.4241
# 283    Topic5   393.317173         favorite place   394.151057   2.4236
# 718    Topic5   391.404356          pollo fundido   392.238230   2.4236
# 170    Topic5   364.560550             cool place   365.405032   2.4235
# 842    Topic5   331.640246           service food   332.474426   2.4233
# 445    Topic5   318.427852            hash browns   319.261887   2.4232
# 404    Topic5   314.943610       great food great   315.777451   2.4231
# 722    Topic5   313.139360             pond ducks   313.973221   2.4231
# 949    Topic5   286.469810              top shelf   287.303663   2.4229
# 213    Topic5   286.473522             don bother   287.307401   2.4229
# 741    Topic5   286.458409            pretty good   287.292291   2.4229
# 935    Topic5   286.402963         thursday night   287.236816   2.4229
# 227    Topic5   286.526383            drinks good   287.366156   2.4228
# 869    Topic5   277.592795              sit patio   278.448719   2.4227
# 2      Topic5   253.437772               3rd time   254.271664   2.4225
# 196    Topic5   245.704619         dinner friends   246.538514   2.4224
# 444    Topic5   245.518280         happy birthday   246.352436   2.4224
# 566    Topic5   237.240016       love place great   238.073857   2.4223
# 314    Topic5   236.718489     food great service   237.552327   2.4223
# 145    Topic5   234.933832            chips salsa   235.767706   2.4222
# 228    Topic5   234.929110              duck pond   235.762987   2.4222
# 136    Topic5   234.917618             cave creek   235.751495   2.4222
# 244    Topic5   234.902758             el encanto   235.736622   2.4222
# 45     Topic5   218.845848          awesome pizza   219.679695   2.4220
# 191    Topic5   218.973543        delicious pizza   219.808250   2.4220
# 422    Topic5   565.047510          great service   770.111541   2.1161
# 519    Topic5   461.578834             late night   792.600562   1.8851
# 403    Topic5   316.676571             great food  2075.882153   0.5455
# 693    Topic5   237.686285            place great   432.905425   1.8262
#
#       logprob
# term
# 403   30.0000
# 565   29.0000
# 415   28.0000
# 727   27.0000
# 377   26.0000
# 422   25.0000
# 312   24.0000
# 391   23.0000
# 519   22.0000
# 329   21.0000
# 25    20.0000
# 383   19.0000
# 283   18.0000
# 718   17.0000
# 170   16.0000
# 877   15.0000
# 135   14.0000
# 225   13.0000
# 455   12.0000
# 800   11.0000
# 633   10.0000
# 880    9.0000
# 608    8.0000
# 895    7.0000
# 222    6.0000
# 432    5.0000
# 573    4.0000
# 842    3.0000
# 469    2.0000
# 445    1.0000
# ...       ...
# 25    -3.6749
# 383   -3.6999
# 283   -3.9110
# 718   -3.9158
# 170   -3.9869
# 842   -4.0815
# 445   -4.1222
# 404   -4.1332
# 722   -4.1389
# 949   -4.2280
# 213   -4.2279
# 741   -4.2280
# 935   -4.2282
# 227   -4.2278
# 869   -4.2594
# 2     -4.3505
# 196   -4.3815
# 444   -4.3822
# 566   -4.4165
# 314   -4.4187
# 145   -4.4263
# 228   -4.4263
# 136   -4.4263
# 244   -4.4264
# 45    -4.4972
# 191   -4.4966
# 422   -3.5487
# 519   -3.7509
# 403   -4.1277
# 693   -4.4146
#
# [220 rows x 6 columns], token_table=      Topic      Freq                          Term
# term
# 2         5  0.994999                      3rd time
# 14        1  0.999128                  amazing food
# 21        1  0.995316             amending previous
# 22        1  0.995316        amending previous post
# 25        5  0.998294                  animal style
# 45        5  0.996906                 awesome pizza
# 46        1  0.995316                back breakfast
# 47        1  0.995316          back breakfast meals
# 58        2  0.998924                       banh mi
# 59        2  0.663261                      bbq pork
# 59        4  0.335259                      bbq pork
# 61        3  0.998611                 beef sandwich
# 68        3  0.998700                    beet salad
# 84        1  0.998838             breakfast burrito
# 92        4  0.998188              breakfast family
# 94        2  0.996633               breakfast lunch
# 95        2  0.996633        breakfast lunch dinner
# 96        1  0.995316               breakfast meals
# 97        1  0.995316           breakfast meals day
# 102       1  0.995716                breakfast spot
# 109       1  0.995316  breakfast wonderful pancakes
# 112       2  0.997453                    bring cash
# 113       3  0.995948                 brought hanny
# 119       1  0.995316                  burgers tuke
# 133       4  0.997549                    call ahead
# 135       3  0.998473         cauliflower calabrese
# 136       5  0.996812                    cave creek
# 145       5  0.996744                   chips salsa
# 152       1  0.997679                  coffee great
# 156       1  0.999023                  comfort food
# ...     ...       ...                           ...
# 878       4  0.994821          slow service madison
# 880       3  0.998702                   snack plate
# 883       2  0.996269                   sounds good
# 890       4  0.994821                    spot place
# 891       4  0.994821        spot place notoriously
# 895       3  0.998946                    st germain
# 914       1  0.995349                 table concept
# 915       1  0.995349      table concept vegetarian
# 917       2  0.996323                    takes long
# 918       2  0.996323               takes long time
# 935       5  0.995694                thursday night
# 940       4  0.998893                    time great
# 941       2  0.996323                    time order
# 942       2  0.996323                time order don
# 945       4  0.997799                     time wait
# 949       5  0.995462                     top shelf
# 950       1  0.492624               torta delicious
# 950       4  0.507781               torta delicious
# 952       4  0.994821                totally rocked
# 953       4  0.994821        totally rocked tonight
# 960       2  0.996323               understand busy
# 967       1  0.996602            vegetarian options
# 973       2  0.994921                     wait back
# 975       1  0.711274                     wait long
# 975       5  0.284509                     wait long
# 977       1  0.995349                     wait wait
# 992       1  0.995316            wonderful pancakes
# 993       1  0.995316     wonderful pancakes coming
# 996       3  0.995948                 youngman line
# 997       3  0.995948             youngman line fun
#
# [200 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[1, 5, 3, 4, 2])
